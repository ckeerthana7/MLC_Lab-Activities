# %% [markdown]
# Recap:
#
#      Machine learning for cybersecurity
#      Applications of Machine learning
#      Cyber
#      Security
#      Cybersecurity
#      Application of Machine learning in cyberecurity
#
#
#      Data
#      Question
#      Information
#      Interpretation
#      Knowledge
#      Decision
#
#
#      Types of Data Analytics
#      Describe
#      Diagnostic
#      Prescriptive
#      predictive
#
#
#      Life cycle of Data Analytics
#      Context
#      problem
#      collect data
#      clean
#      EDA
#      Model
#      Visualize
#      Decision
#
#
#      Types of Data
#      Based on Representation
#        Structure
# Unstructured
#        Semi-Structure
#        Loading files
#
#      Based on values
# Qualitative
#           Nominal
#           Ordinal
#         Quantitative
#           Discrete
#           Continuous
#
#       Importance of values
# Analysis         Operations
#             - Arithmetic
#             - Aggregation
#             - Count
#             - Distribution
#             - Frequency
#             - Ramk
#             - Comparision
#
#        Lab Activity:
#
#        - Mount google drive
#        - Load the files
#        - Convert the files in to dataframe
#
#
#        - Inspecting the datafram
#               - find the total number of records and features
#               - find the number of records
#               - find the number of features
#               - find the data types
#               - find the summary of datafram
#               - find the statistical details of dataframe

# %% [markdown]
# Contents
#
#      Types of Data : Sources
#
#       Collection
#          Primary
#          Secondary
#
#       Nature
#          Real
#          Simulation
#          Emulated
#
#       Ownership
#          Internal
#          External
#
#       Layer
#          Application
#          Network
#          Network device
#          Host
#          IoT devices
#          Virtual Environments

# %% [markdown]
# Activity: 1
# Task    : 1
#
# A cybersecurity analyst collects HTTP access logs from a college web portal to analyze multiple failed login attempts and detect brute-force attacks.
#
# Identify:
#
# Collection Method  : Primary
#
# Nature             : real
#
# Ownership          : internal
#
# Layer              : application

# %% [markdown]
# Activity :1
#
# Task     :2
#
# A researcher uses Mininet to create a virtual SDN topology with Open vSwitch and a POX controller. ICMP flood attacks are generated using hping3, and packet captures are stored for machine-learning analysis.
#
# Students Identify:
#
# Collection Method: primary
#
# Nature: emulated
#
# Ownership: internal
#
# Layer: Network

# %% [markdown]
# Activity :1
#
# Task     :3
#
# A student downloads the CIC-IDS dataset from an online repository and uses it to train a Random Forest model for intrusion detection.
#
# Students Identify:
#
# Collection Method: secondary
#
# Nature: simulated
#
# Ownership: external
#
# Layer: application

# %% [markdown]
# Activity :1
#
# Task     :4
#
# A student writes a script to generate artificial network traffic patterns without running real network protocols and uses this data to test an ML model.
#
# Students Identify:
#
# Collection Method: primary
#
# Nature: emulated
#
# Ownership: internal
#
# Layer: network

# %% [markdown]
# Activity 2: Identify & Justify
#
# For each tool, identify whether it is simulation or emulation and justify in one line.
#
#    Mininet - emulated
#
#    NS-3 - simulation
#
#    Wireshark on live traffic - real
#
#    Synthetic traffic generator - simulation

# %% [markdown]
# Activity 3:
#
# Task     1:
#
# A system administrator collects authentication logs showing repeated failed login attempts from the same IP address.
#
#
# | Item             | Identify                                    |
# | ---------------- | -------------------------------------------------------- |
# | Data Source      |                                                          |
# | Example Features | Failed login count, time gap between attempts            |
# | ML Task          |                                                          |
# | Reason           |                                                          |

# %% [markdown]
# Activity 3:
#
# Task     2:
#
# HTTP request logs are analyzed to detect SQL injection attempts.
#
# | Item             | Identify                                 |
# | ---------------- | ---------------------------------------------------- |
# | Data Source      |                             |
# | Example Features |                             |
# | ML Task          |                             |
# | Reason           |                             |

# %% [markdown]
# Activity 3:
#
# Task 3:
#
# A security team observes that on several machines, a single program starts spawning multiple child processes within a short time. The same program also consumes unusually high CPU and memory, and several system files are accessed repeatedly within seconds. No abnormal network traffic is observed during this period.
#
# | Item                 |  Response        |
# | -------------------- | ---------------- |
# | **Data Source**      | __________       |
# | **Example Features** | __________       |
# | **ML Task**          | __________       |
# | **Reason**           | __________       |
