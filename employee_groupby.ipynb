# %% [markdown]
# <a href="https://colab.research.google.com/github/ckeerthana7/MLC_Lab-Activities/blob/main/employee_groupby.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DIR = '/content/drive/My Drive/Colab Notebooks/mlc'
datafile = 'employee.csv'
filename = DIR+'/'+datafile

# %%
import os
os.chdir(DIR)

# %%
df = pd.read_csv(filename)
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# Group By

# %%
df['Department'].unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
df.groupby('Department').size()
# Out:
# Department
# Human Resources            63
# Research & Development    961
# Sales                     446
# dtype: int64

# %%
df.groupby('Department').size().plot(kind='bar')
# Out:
# <Axes: xlabel='Department'>

# %%
df.groupby('EducationField').size()
# Out:
# EducationField
# Human Resources      27
# Life Sciences       606
# Marketing           159
# Medical             464
# Other                82
# Technical Degree    132
# dtype: int64

# %%
df.groupby('EducationField').size().plot(kind='bar')
# Out:
# <Axes: xlabel='EducationField'>

# %%
df.groupby('BusinessTravel').size()
# Out:
# BusinessTravel
# Non-Travel            150
# Travel_Frequently     277
# Travel_Rarely        1043
# dtype: int64

# %%
df.groupby('BusinessTravel').size().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: >

# %%
df.groupby('BusinessTravel').ngroups
# Out:
# 3

# %%
#count for all the features
df.groupby('BusinessTravel').count()
# Out:
#                     Age  Attrition  DailyRate  Department  DistanceFromHome  \
# BusinessTravel
# Non-Travel          150        150        150         150               150
# Travel_Frequently   277        277        277         277               277
# Travel_Rarely      1043       1043       1043        1043              1043
#
#                    Education  EducationField  EmployeeCount  EmployeeNumber  \
# BusinessTravel
# Non-Travel               150             150            150             150
# Travel_Frequently        277             277            277             277
# Travel_Rarely           1043            1043           1043            1043
#
#                    EnvironmentSatisfaction  ...  RelationshipSatisfaction  \
# BusinessTravel                              ...
# Non-Travel                             150  ...                       150
# Travel_Frequently                      277  ...                       277
# ...

# %%
dir(df.groupby('BusinessTravel'))
# Out:
# ['Age',
#  'Attrition',
#  'BusinessTravel',
#  'DailyRate',
#  'Department',
#  'DistanceFromHome',
#  'Education',
#  'EducationField',
#  'EmployeeCount',
#  'EmployeeNumber',
#  'EnvironmentSatisfaction',
#  'Gender',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobRole',
#  'JobSatisfaction',
#  'MaritalStatus',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'Over18',
#  'OverTime',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StandardHours',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager',
#  '_DataFrameGroupBy__examples_dataframe_doc',
#  '__annotations__',
#  '__class__',
#  '__class_getitem__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
# ...

# %%
df.groupby('BusinessTravel').all()
# Out:
#                     Age  Attrition  DailyRate  Department  DistanceFromHome  \
# BusinessTravel
# Non-Travel         True       True       True        True              True
# Travel_Frequently  True       True       True        True              True
# Travel_Rarely      True       True       True        True              True
#
#                    Education  EducationField  EmployeeCount  EmployeeNumber  \
# BusinessTravel
# Non-Travel              True            True           True            True
# Travel_Frequently       True            True           True            True
# Travel_Rarely           True            True           True            True
#
#                    EnvironmentSatisfaction  ...  RelationshipSatisfaction  \
# BusinessTravel                              ...
# Non-Travel                            True  ...                      True
# Travel_Frequently                     True  ...                      True
# ...

# %%
df.groupby('BusinessTravel').max()
# Out:
#                    Age Attrition  DailyRate Department  DistanceFromHome  \
# BusinessTravel
# Non-Travel          59       Yes       1496      Sales                29
# Travel_Frequently   60       Yes       1499      Sales                29
# Travel_Rarely       60       Yes       1498      Sales                29
#
#                    Education    EducationField  EmployeeCount  EmployeeNumber  \
# BusinessTravel
# Non-Travel                 5  Technical Degree              1            2057
# Travel_Frequently          5  Technical Degree              1            2065
# Travel_Rarely              5  Technical Degree              1            2068
#
#                    EnvironmentSatisfaction  ... RelationshipSatisfaction  \
# BusinessTravel                              ...
# Non-Travel                               4  ...                        4
# Travel_Frequently                        4  ...                        4
# ...

# %%
#find the average size of each department
df.groupby('Department').size().mean()
# Out:
# np.float64(490.0)

# %%
df.groupby('Department').size().min()
# Out:
# 63

# %%
df.groupby('Department').aggregate({'MonthlyIncome':['min','max','mean']})
# Out:
#                        MonthlyIncome
#                                  min    max         mean
# Department
# Human Resources                 1555  19717  6654.507937
# Research & Development          1009  19999  6281.252862
# Sales                           1052  19847  6959.172646

# %%
df.groupby('Department').agg({'MonthlyIncome':['min','max','mean'],'Age':['min','max','mean']})
# Out:
#                        MonthlyIncome                     Age
#                                  min    max         mean min max       mean
# Department
# Human Resources                 1555  19717  6654.507937  19  59  37.809524
# Research & Development          1009  19999  6281.252862  18  60  37.042664
# Sales                           1052  19847  6959.172646  18  60  36.542601

# %%
df.groupby('Department').size().diff()
# Out:
# Department
# Human Resources             NaN
# Research & Development    898.0
# Sales                    -515.0
# dtype: float64

# %%
df.groupby('JobRole').aggregate({'MonthlyIncome':['min','max','mean']}).plot(kind='barh', stacked = True)
# Out:
# <Axes: ylabel='JobRole'>
