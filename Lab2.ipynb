# %%
# !ls
# Out:
# sample_data

# %%
# !pwd
# Out:
# /content

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# drive  sample_data
# drive  sample_data

# %%
DIR = '/content/drive/My Drive/Colab Notebooks/data'
datafile = 'auth_logs.csv'
filename = DIR+'/'+datafile

# %%
import os
os.chdir(DIR)

# %%
df = pd.read_csv(filename)
df
# Out:
#                timestamp username          ip   status   role    country
# 0    2026-01-05 09:00:10   walter  10.0.0.104  SUCCESS  admin    Germany
# 1    2026-01-05 09:00:31   victor  10.0.0.128  SUCCESS   user        USA
# 2    2026-01-05 09:01:00  charlie  10.0.0.162  SUCCESS   user        USA
# 3    2026-01-05 09:01:34    trent   10.0.0.99  SUCCESS   user        UAE
# 4    2026-01-05 09:02:03   victor  10.0.0.222   FAILED   user        USA
# ..                   ...      ...         ...      ...    ...        ...
# 115  2026-01-05 09:57:38   walter  10.0.0.208   FAILED   user  Australia
# 116  2026-01-05 09:58:08    trent  10.0.0.213   FAILED   user  Singapore
# 117  2026-01-05 09:58:34      bob   10.0.0.73   FAILED   user  Australia
# 118  2026-01-05 09:59:09   walter  10.0.0.158  SUCCESS   user  Australia
# 119  2026-01-05 09:59:36  mallory   10.0.0.48  SUCCESS   user        UAE
#
# [120 rows x 6 columns]

# %%
df.dtypes
# Out:
# timestamp    object
# username     object
# ip           object
# status       object
# role         object
# country      object
# dtype: object

# %%
df.columns
# Out:
# Index(['timestamp', 'username', 'ip', 'status', 'role', 'country'], dtype='object')

# %%
datafile = 'dns_queries.tsv'
filename = DIR+'/'+datafile

# %%
df = pd.read_csv(filename, sep = '\t')
df
# Out:
#                timestamp      src_ip           query  qtype     rcode  \
# 0    2026-01-05 09:00:10   10.0.0.89    evil.example     MX  SERVFAIL
# 1    2026-01-05 09:00:31  10.0.0.144     example.com     MX   NOERROR
# 2    2026-01-05 09:01:00   10.0.0.63  updates.vendor    TXT  SERVFAIL
# 3    2026-01-05 09:01:34  10.0.0.178    mail.example    TXT  NXDOMAIN
# 4    2026-01-05 09:02:03   10.0.0.25    evil.example   AAAA  NXDOMAIN
# ..                   ...         ...             ...    ...       ...
# 115  2026-01-05 09:57:38  10.0.0.119     example.com      A  NXDOMAIN
# 116  2026-01-05 09:58:08  10.0.0.111        msis.edu    TXT  SERVFAIL
# 117  2026-01-05 09:58:34   10.0.0.20        msis.edu  CNAME  SERVFAIL
# 118  2026-01-05 09:59:09   10.0.0.18      github.com  CNAME  SERVFAIL
# 119  2026-01-05 09:59:36   10.0.0.99    evil.example    TXT  SERVFAIL
#
#      answer_count
# 0               2
# 1               0
# 2               1
# 3               0
# 4               1
# ...

# %%
df = pd.read_excel('soc_alerts.xlsx')
df
# Out:
#                 timestamp      tool           event_type  severity  \
# 0    2026-01-05T09:00:10Z  Defender                  XSS    medium
# 1    2026-01-05T09:00:31Z       EDR      SuspiciousLogin      high
# 2    2026-01-05T09:01:00Z  Defender                  XSS      high
# 3    2026-01-05T09:01:34Z       IDS  PrivilegeEscalation    medium
# 4    2026-01-05T09:02:03Z       WAF                  XSS  critical
# ..                    ...       ...                  ...       ...
# 115  2026-01-05T09:57:38Z       IDS            DataExfil    medium
# 116  2026-01-05T09:58:08Z       IDS      SuspiciousLogin  critical
# 117  2026-01-05T09:58:34Z       IDS  PrivilegeEscalation    medium
# 118  2026-01-05T09:59:09Z      SIEM            DataExfil      high
# 119  2026-01-05T09:59:36Z      SIEM            DataExfil    medium
#
#          src_ip             dest                                  message
# 0     10.0.0.27          /upload              Suspicious process behavior
# ...

# %%
df = pd.read_json('superstore_json.json')
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156  11-08-2016  11-11-2016    Second Class
# 1          2  CA-2016-152156  11-08-2016  11-11-2016    Second Class
# 2          3  CA-2016-138688  06-12-2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10-11-2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10-11-2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017  03-03-2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017  03-03-2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017  03-03-2017  Standard Class
# 9993    9994  CA-2017-119914  05-04-2017  05-09-2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df = pd.read_json('netflow.jsonl', lines = True)
df
# Out:
#                     timestamp      src_ip      dst_ip  dst_port proto  bytes  \
# 0   2026-01-05 09:00:10+00:00   10.0.0.92   10.0.0.14        22   UDP   8208
# 1   2026-01-05 09:00:31+00:00   10.0.0.75  10.0.0.139        22   TCP   7160
# 2   2026-01-05 09:01:00+00:00  10.0.0.188   10.0.0.95        25   UDP   6095
# 3   2026-01-05 09:01:34+00:00   10.0.0.15  10.0.0.147      3389   TCP   6039
# 4   2026-01-05 09:02:03+00:00   10.0.0.20  10.0.0.100      3389   UDP  12623
# ..                        ...         ...         ...       ...   ...    ...
# 115 2026-01-05 09:57:38+00:00  10.0.0.112  10.0.0.116      3389   UDP   1792
# 116 2026-01-05 09:58:08+00:00   10.0.0.92  10.0.0.143        22   UDP  14251
# 117 2026-01-05 09:58:34+00:00   10.0.0.76  10.0.0.107        53   TCP  11975
# 118 2026-01-05 09:59:09+00:00  10.0.0.148  10.0.0.135        80   UDP   2877
# 119 2026-01-05 09:59:36+00:00   10.0.0.79   10.0.0.70        53   TCP   1136
#
#      packets action
# 0         39   DENY
# ...

# %%
df = pd.read_csv('superstore.txt', sep = '\t')
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156  11-08-2016  11-11-2016    Second Class
# 1          2  CA-2016-152156  11-08-2016  11-11-2016    Second Class
# 2          3  CA-2016-138688  06-12-2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10-11-2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10-11-2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017  03-03-2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017  03-03-2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017  03-03-2017  Standard Class
# 9993    9994  CA-2017-119914  05-04-2017  05-09-2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df = pd.read_xml('ioc_feed.xml')
df
# Out:
#             type                                              value confidence
# 0            url                         http://phish.example/login        low
# 1         domain                                      phish.example       high
# 2    hash_sha256  b0b46f95f121770f0a64a5a10443b2bc3a9a45dfa5b75c...        low
# 3             ip                                         10.0.0.212       high
# 4    hash_sha256  e08672b8301ced5dfcbc3f75e2190a832a5c522af0d5d5...     medium
# ..           ...                                                ...        ...
# 115          url                            http://mal.example/drop        low
# 116       domain                                     badcdn.example       high
# 117           ip                                         10.0.0.144     medium
# 118           ip                                          10.0.0.50     medium
# 119          url                            http://mal.example/drop     medium
#
# [120 rows x 3 columns]

# %%
df = pd.read_yml('security_policy.yml')
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2803823399.py in <cell line: 0>()
# ----> 1 df = pd.read_yml('security_policy.yml')
#       2 df
#
# AttributeError: module 'pandas' has no attribute 'read_yml'

# %%
import sqlite3
conn = sqlite3.connect(':memory:')
df = pd.read_sql('soc_dump.sql', conn)
df
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2673         try:
# -> 2674             cur.execute(sql, *args)
#    2675             return cur
#
# OperationalError: near "soc_dump": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# /tmp/ipython-input-2296976430.py in <cell line: 0>()
#       1 import sqlite3
#       2 conn = sqlite3.connect(':memory:')
# ----> 3 df = pd.read_sql('soc_dump.sql', conn)
#       4 df
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     704     with pandasSQL_builder(con) as pandas_sql:
# ...

# %%
df = pd.read_csv('web_access.log', sep=" ")
df
# Out:
#      2026-01-05T09:00:10Z   10.0.0.72  DELETE          /reset  403   830  \
# 0    2026-01-05T09:00:31Z   10.0.0.66    POST       /settings  500  1801
# 1    2026-01-05T09:01:00Z   10.0.0.29    POST          /reset  200  3441
# 2    2026-01-05T09:01:34Z  10.0.0.217  DELETE         /search  403  2942
# 3    2026-01-05T09:02:03Z  10.0.0.210    POST          /reset  400  1845
# 4    2026-01-05T09:02:33Z   10.0.0.82    POST         /upload  400  2587
# ..                    ...         ...     ...             ...  ...   ...
# 114  2026-01-05T09:57:38Z  10.0.0.243  DELETE          /login  200  4901
# 115  2026-01-05T09:58:08Z  10.0.0.212  DELETE       /settings  200  3335
# 116  2026-01-05T09:58:34Z   10.0.0.46     PUT  /api/v1/orders  200  2452
# 117  2026-01-05T09:59:09Z  10.0.0.116    POST          /login  500  2213
# 118  2026-01-05T09:59:36Z  10.0.0.129  DELETE       /settings  200   918
#
#      python-requests/2.31
# 0     PostmanRuntime/7.35
# 1    python-requests/2.31
# ...

# %%
# !pip install dbfread
from dbfread import DBF

# %%
dbf = DBF('superstore.dbf', encoding = 'latin -1')
df = pd.DataFrame(dbf)
df
# Out:
#      N___ROW_ID        ORDER_ID  ORDER_DATE   SHIP_DATE       SHIP_MODE  \
# 0             1  CA-2016-152156  11-08-2016  11-11-2016    Second Class
# 1             2  CA-2016-152156  11-08-2016  11-11-2016    Second Class
# 2             3  CA-2016-138688  06-12-2016   6/16/2016    Second Class
# 3             4  US-2015-108966  10-11-2015  10/18/2015  Standard Class
# 4             5  US-2015-108966  10-11-2015  10/18/2015  Standard Class
# ..          ...             ...         ...         ...             ...
# 271         272  CA-2015-155334   7/30/2015   7/31/2015     First Class
# 272         273  CA-2015-155334   7/30/2015   7/31/2015     First Class
# 273         274  CA-2015-155334   7/30/2015   7/31/2015     First Class
# 274         275  CA-2017-118136   9/16/2017   9/17/2017     First Class
# 275         276  CA-2017-118136   9/16/2017   9/17/2017     First Class
#
#     CUSTOMER_I       CUSTOMER_N    SEGMENT        COUNTRY             CITY  \
# ...
