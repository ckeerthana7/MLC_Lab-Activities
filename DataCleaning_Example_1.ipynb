# %% [markdown]
# <a href="https://colab.research.google.com/github/ckeerthana7/MLC_Lab-Activities/blob/main/DataCleaning_Example_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Cleaning In Python
#
# ### Common Issues With Data
# + Reading the file
# + Inconsistent Column Names
# + Missing Data
# + Different Data Types
# + Duplicate rows
# + etc

# %%
# import packages
import pandas as pd
#import numpy as np

# %%
# To mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import re
os.chdir(DIR)

# %%
DIR = '/content/drive/My Drive/Colab Notebooks/mlc'
datafile1 = 'raw_dataset.csv'
datafile2 = 'unclean_data.csv'
filename1 = DIR+'/'+datafile1
filename2 = DIR+'/'+datafile2

# %%
datafile3 = 'earthquakes.csv'
datafile4 = '3_cereal.csv'
filename3 = DIR+'/'+datafile3
filename4 = DIR+'/'+datafile4

# %%
df1 = pd.read_csv(filename1)
df1
# Out:
#    irst Name  Last name         Age  SALARY            STREET Address1  \
# 0       Joel    Padilla  10/28/2019  $92.32           431-6530 Eu, Rd.
# 1      Fritz      Tyler  09/27/2019  $83.91        Ap #377-2267 Ac Av.
# 2       Wing     Phelps  02/18/2019  $17.15  Ap #545-5786 Pulvinar Ave
# 3       Ryan       Ross  05/21/2019  $45.97           634-7858 Id Road
# 4      Drake        Day  01/09/2020  $84.38       999-8221 Tempor, St.
# ..       ...        ...         ...     ...                        ...
# 95    Victor      Hobbs  05/24/2019  $54.56             4034 Vitae St.
# 96      Neil   Bradford  02/07/2020  $74.52       1434 Aliquet, Street
# 97     Noble     Conrad  10/29/2019  $43.99     Ap #173-7049 Eget, St.
# 98     Brody   Whitaker  08/09/2018  $96.24   Ap #371-9803 Aliquam Rd.
# 99     Alden  Mccormick  07/27/2019   $2.66   Ap #375-1139 Risus. Road
#
#                  STREET Address2                 STREET Address3  \
# ...

# %%
df3 = pd.read_csv(filename3)
df3

# %%
df4 = pd.read_csv(filename4)
df4

# %% [markdown]
# ## Loading or Reading the File
# + Encoding Error
# + Inconsistent rows

# %%
# Issue 1
df2 = pd.read_csv(filename2)
df2
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /tmp/ipython-input-2278704107.py in <cell line: 0>()
#       1 # Issue 1
# ----> 2 df2 = pd.read_csv(filename2)
#       3 df2
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
# Solution 1
# UTF Encoding
df2 = pd.read_csv(filename2, encoding='latin1')
df2
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %%
df1.head()
# Out:
#   irst Name Last name         Age  SALARY            STREET Address1  \
# 0      Joel   Padilla  10/28/2019  $92.32           431-6530 Eu, Rd.
# 1     Fritz     Tyler  09/27/2019  $83.91        Ap #377-2267 Ac Av.
# 2      Wing    Phelps  02/18/2019  $17.15  Ap #545-5786 Pulvinar Ave
# 3      Ryan      Ross  05/21/2019  $45.97           634-7858 Id Road
# 4     Drake       Day  01/09/2020  $84.38       999-8221 Tempor, St.
#
#                 STREET Address2                 STREET Address3  \
# 0            364-2264 Augue Rd.  P.O. Box 864, 3882 Orci Street
# 1              979-2228 Vel Ave                     9865 Eu Av.
# 2  Ap #973-5781 Sagittis Avenue                     9959 Ut St.
# 3        907-8824 Fringilla Ave                 318-5271 In Ave
# 4          297-6939 Turpis. Ave  P.O. Box 638, 6932 Laoreet Rd.
#
#                                   email
# 0                           eu@nibh.com
# 1  est.ac.mattis@malesuadafringilla.net
# 2                     dolor@cubilia.net
# ...

# %%
# Solution 2
# Use Text Editor and Save it as Utf-8,ISO-8859-1,latin1
df2 = pd.read_csv(filename2, encoding='ISO-8859-1')
df2
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %%
datafile3 = 'cleaned.csv'
filename3 = DIR+'/'+datafile3

# %%
df3 = pd.read_csv(filename3, encoding='utf-8')
df3
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %%
df2.head()
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %% [markdown]
# ## Inconsistent Column Names
# + Change Cases
# + Rename them

# %% [markdown]
# ### Change the case to Upper

# %%
df1.columns
# Out:
# Index(['irst Name', 'Last name', 'Age', 'SALARY', 'STREET Address1',
#        'STREET Address2', 'STREET Address3', 'email'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['movie_title', 'num_critic_for_reviews', 'duration',
#        'DIRECTOR_facebook_likes', 'actor_3_facebook_likes',
#        'ACTOR_1_facebook_likes', 'gross', 'num_voted_users',
#        'Cast_Total_facebook_likes', 'facenumber_in_poster',
#        'num_user_for_reviews', 'budget', 'title_year',
#        'ACTOR_2_facebook_likes', 'imdb_score', 'title_year.1'],
#       dtype='object')

# %%
df1.columns = df1.columns.str.strip().str.lower().str.replace(' ', '_')
df1.columns
# Out:
# Index(['first_name', 'last_name', 'age', 'salary', 'street_address1',
#        'street_address2', 'street_address3', 'email'],
#       dtype='object')

# %%
df1.rename(columns={'irst_name': 'First_name'}, inplace=True)
df1.columns
# Out:
# Index(['first_name', 'last_name', 'age', 'salary', 'street_address1',
#        'street_address2', 'street_address3', 'email'],
#       dtype='object')

# %%
df1.columns = df1.columns.str.strip().str.upper()
df1.columns
# Out:
# Index(['FIRST_NAME', 'LAST_NAME', 'AGE', 'SALARY', 'STREET_ADDRESS1',
#        'STREET_ADDRESS2', 'STREET_ADDRESS3', 'EMAIL'],
#       dtype='object')

# %%
df2.columns = df2.columns.str.strip().str.lower().str.replace(' ', '_')
df2.columns
# Out:
# Index(['movie_title', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes',
#        'actor_1_facebook_likes', 'gross', 'num_voted_users',
#        'cast_total_facebook_likes', 'facenumber_in_poster',
#        'num_user_for_reviews', 'budget', 'title_year',
#        'actor_2_facebook_likes', 'imdb_score', 'title_year.1'],
#       dtype='object')

# %%
df2.columns = df2.columns.str.strip().str.upper()
df2.columns
# Out:
# Index(['MOVIE_TITLE', 'NUM_CRITIC_FOR_REVIEWS', 'DURATION',
#        'DIRECTOR_FACEBOOK_LIKES', 'ACTOR_3_FACEBOOK_LIKES',
#        'ACTOR_1_FACEBOOK_LIKES', 'GROSS', 'NUM_VOTED_USERS',
#        'CAST_TOTAL_FACEBOOK_LIKES', 'FACENUMBER_IN_POSTER',
#        'NUM_USER_FOR_REVIEWS', 'BUDGET', 'TITLE_YEAR',
#        'ACTOR_2_FACEBOOK_LIKES', 'IMDB_SCORE', 'TITLE_YEAR.1'],
#       dtype='object')

# %% [markdown]
# ### Renaming Columns

# %%
# rename the column DURATION to TIME
df2.rename(columns={'DURATION': 'TIME'}, inplace=True)
df2.columns
# Out:
# Index(['MOVIE_TITLE', 'NUM_CRITIC_FOR_REVIEWS', 'TIME',
#        'DIRECTOR_FACEBOOK_LIKES', 'ACTOR_3_FACEBOOK_LIKES',
#        'ACTOR_1_FACEBOOK_LIKES', 'GROSS', 'NUM_VOTED_USERS',
#        'CAST_TOTAL_FACEBOOK_LIKES', 'FACENUMBER_IN_POSTER',
#        'NUM_USER_FOR_REVIEWS', 'BUDGET', 'TITLE_YEAR',
#        'ACTOR_2_FACEBOOK_LIKES', 'IMDB_SCORE', 'TITLE_YEAR.1'],
#       dtype='object')

# %% [markdown]
# ## Missing Data
# + Add a default value for missing data or use mean to fill it
# + Delete the row/column with missing data
# + Interpolate the rows
# + Replace

# %%
#Add a default value for missing data or use mean to fill it
df2.fillna(0, inplace=True)

# %%
df2
# Out:
#                                      MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %%
#Interpolate the rows

# %%
df2.dtypes
# Out:
# MOVIE_TITLE                   object
# NUM_CRITIC_FOR_REVIEWS         int64
# TIME                         float64
# DIRECTOR_FACEBOOK_LIKES       object
# ACTOR_3_FACEBOOK_LIKES         int64
# ACTOR_1_FACEBOOK_LIKES         int64
# GROSS                          int64
# NUM_VOTED_USERS              float64
# CAST_TOTAL_FACEBOOK_LIKES    float64
# FACENUMBER_IN_POSTER         float64
# NUM_USER_FOR_REVIEWS           int64
# BUDGET                         int64
# TITLE_YEAR                     int64
# ACTOR_2_FACEBOOK_LIKES       float64
# IMDB_SCORE                   float64
# TITLE_YEAR.1                 float64
# dtype: object

# %% [markdown]
# #### To check for missing data
# #### False means no missing data
# + df.isnull().sum() int
# + df.isnull().any() bool

# %%
# check is there missing data
# Out:
#     MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS  DURATION  DIRECTOR_FACEBOOK_LIKES  \
# 0         False                   False     False                    False
# 1         False                   False      True                    False
# 2         False                   False     False                    False
# 3         False                   False      True                    False
# 4         False                   False     False                    False
# 5         False                   False     False                    False
# 6         False                   False      True                    False
# 7         False                   False     False                    False
# 8         False                   False     False                    False
# 9         False                   False     False                    False
# 10        False                   False     False                     True
# ...

# %%
# using any
# Out:
# MOVIE_TITLE                  False
# NUM_CRITIC_FOR_REVIEWS       False
# DURATION                      True
# DIRECTOR_FACEBOOK_LIKES       True
# ACTOR_3_FACEBOOK_LIKES       False
# ACTOR_1_FACEBOOK_LIKES       False
# GROSS                        False
# NUM_VOTED_USERS               True
# CAST_TOTAL_FACEBOOK_LIKES     True
# FACENUMBER_IN_POSTER          True
# NUM_USER_FOR_REVIEWS         False
# BUDGET                       False
# TITLE_YEAR                   False
# ACTOR_2_FACEBOOK_LIKES        True
# IMDB_SCORE                   False
# TITLE_YEAR.1                  True
# dtype: bool

# %%
# Count how many missing values
# Out:
# MOVIE_TITLE                  0
# NUM_CRITIC_FOR_REVIEWS       0
# DURATION                     3
# DIRECTOR_FACEBOOK_LIKES      2
# ACTOR_3_FACEBOOK_LIKES       0
# ACTOR_1_FACEBOOK_LIKES       0
# GROSS                        0
# NUM_VOTED_USERS              1
# CAST_TOTAL_FACEBOOK_LIKES    2
# FACENUMBER_IN_POSTER         5
# NUM_USER_FOR_REVIEWS         0
# BUDGET                       0
# TITLE_YEAR                   0
# ACTOR_2_FACEBOOK_LIKES       1
# IMDB_SCORE                   0
# TITLE_YEAR.1                 7
# dtype: int64

# %%
# Total Number of Missing NA
# Out:
# 21

# %% [markdown]
# ### Adding A Default Value or Filling the Missing Data

# %%
df.head()
# Out:
#                                   MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    DURATION DIRECTOR_FACEBOOK_LIKES  ACTOR_3_FACEBOOK_LIKES  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_FACEBOOK_LIKES      GROSS  NUM_VOTED_USERS  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %%
# default value with 0

# %%
# Out:
#                                   MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    DURATION DIRECTOR_FACEBOOK_LIKES  ACTOR_3_FACEBOOK_LIKES  \
# 0     178.0                      10                     855
# 1       0.0                     563                    1000
# 2     148.0                      20                     161
# 3       0.0                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_FACEBOOK_LIKES      GROSS  NUM_VOTED_USERS  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %% [markdown]
# #### Fill it with the mean

# %%
# Fill it with the mean
# Out:
# 150.72727272727272

# %%
df_with_mean
# Out:
# 0     178.000000
# 1     150.727273
# 2     148.000000
# 3     150.727273
# 4     132.000000
# 5     156.000000
# 6     150.727273
# 7     141.000000
# 8     141.000000
# 9     153.000000
# 10    183.000000
# 11    169.000000
# 12    106.000000
# 13    151.000000
# Name: DURATION, dtype: float64

# %% [markdown]
# ### Droping NA

# %%
## Droping NA
df.head()
# Out:
#                                   MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    DURATION DIRECTOR_FACEBOOK_LIKES  ACTOR_3_FACEBOOK_LIKES  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_FACEBOOK_LIKES      GROSS  NUM_VOTED_USERS  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %%
# find the shape
df_drop.shape

# %%
df_drop.head()
# Out:
#                                      MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS  \
# 2                                      Spectre?ÿ                     602
# 8                      Avengers: Age of Ultron?ÿ                     635
# 12                           Quantum of Solace?ÿ                     403
# 13  Pirates of the Caribbean: Dead Man's Chest?ÿ                     313
#
#     DURATION DIRECTOR_FACEBOOK_LIKES  ACTOR_3_FACEBOOK_LIKES  \
# 2      148.0                      20                     161
# 8      141.0                      10                   19000
# 12     106.0                     395                     393
# 13     151.0                     563                    1000
#
#     ACTOR_1_FACEBOOK_LIKES      GROSS  NUM_VOTED_USERS  \
# 2                    11000  200074175         275868.0
# 8                    26000  458991599         462669.0
# 12                     451  168368427         330784.0
# 13                   40000  423032628         522040.0
#
# ...

# %% [markdown]
# # DATA CLEANING IN PYTHON

# %% [markdown]
# ## Dropping Duplicates
#  + drop_duplicates()
#  + keep='first'

# %%
df = pd.read_csv("unclean_data1.csv",encoding='utf8')

# %%
df_drop_dup = df.drop_duplicates('MOVIE_TITLE')

# %%
df_drop_dup.shape
# Out:
# (13, 16)

# %% [markdown]
# ## Data Types Inconsistencies
#  + Change datatype after reading the csv
