# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DIR = '/content/drive/My Drive/Colab Notebooks/data'
datafile= 'superstore.csv'
filename = DIR+'/'+datafile

# %%
import os
os.chdir(DIR)

# %%
df = pd.read_csv(filename)

# %%
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156  11-08-2016  11-11-2016    Second Class
# 1          2  CA-2016-152156  11-08-2016  11-11-2016    Second Class
# 2          3  CA-2016-138688  06-12-2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10-11-2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10-11-2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017  03-03-2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017  03-03-2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017  03-03-2017  Standard Class
# 9993    9994  CA-2017-119914  05-04-2017  05-09-2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.columns.str.replace(" ", "_")
# Out:
# Index(['Row_ID', 'Order_ID', 'Order_Date', 'Ship_Date', 'Ship_Mode',
#        'Customer_ID', 'Customer_Name', 'Segment', 'Country', 'City', 'State',
#        'Postal_Code', 'Region', 'Product_ID', 'Category', 'Sub-Category',
#        'Product_Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Row_ID', 'Order_ID', 'Order_Date', 'Ship_Date', 'Ship_Mode',
#        'Customer_ID', 'Customer_Name', 'Segment', 'Country', 'City', 'State',
#        'Postal_Code', 'Region', 'Product_ID', 'Category', 'Sub-Category',
#        'Product_Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.columns.str.replace("-", "_")
# Out:
# Index(['Row_ID', 'Order_ID', 'Order_Date', 'Ship_Date', 'Ship_Mode',
#        'Customer_ID', 'Customer_Name', 'Segment', 'Country', 'City', 'State',
#        'Postal_Code', 'Region', 'Product_ID', 'Category', 'Sub_Category',
#        'Product_Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Row_ID             int64
# Order_ID          object
# Order_Date        object
# Ship_Date         object
# Ship_Mode         object
# Customer_ID       object
# Customer_Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal_Code        int64
# Region            object
# Product_ID        object
# Category          object
# Sub-Category      object
# Product_Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
df["Order_Date"] = pd.to_datetime(df["Order_Date"], errors="coerce")

# %%
df.dtypes
# Out:
# Row_ID                    int64
# Order_ID                 object
# Order_Date       datetime64[ns]
# Ship_Date                object
# Ship_Mode                object
# Customer_ID              object
# Customer_Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal_Code               int64
# Region                   object
# Product_ID               object
# Category                 object
# Sub-Category             object
# Product_Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %%
df["Ship_Date"] = pd.to_datetime(df["Ship_Date"], errors="coerce")

# %%
df.dtypes
# Out:
# Row_ID                    int64
# Order_ID                 object
# Order_Date       datetime64[ns]
# Ship_Date        datetime64[ns]
# Ship_Mode                object
# Customer_ID              object
# Customer_Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal_Code               int64
# Region                   object
# Product_ID               object
# Category                 object
# Sub-Category             object
# Product_Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %%
df.isna().count()
# Out:
# Row_ID           9994
# Order_ID         9994
# Order_Date       9994
# Ship_Date        9994
# Ship_Mode        9994
# Customer_ID      9994
# Customer_Name    9994
# Segment          9994
# Country          9994
# City             9994
# State            9994
# Postal_Code      9994
# Region           9994
# Product_ID       9994
# Category         9994
# Sub-Category     9994
# Product_Name     9994
# Sales            9994
# Quantity         9994
# Discount         9994
# Profit           9994
# dtype: int64

# %%
df.notna().count()
# Out:
# Row_ID           9994
# Order_ID         9994
# Order_Date       9994
# Ship_Date        9994
# Ship_Mode        9994
# Customer_ID      9994
# Customer_Name    9994
# Segment          9994
# Country          9994
# City             9994
# State            9994
# Postal_Code      9994
# Region           9994
# Product_ID       9994
# Category         9994
# Sub-Category     9994
# Product_Name     9994
# Sales            9994
# Quantity         9994
# Discount         9994
# Profit           9994
# dtype: int64

# %% [markdown]
# DATA ACCESS

# %%
df.iloc[0]
# Out:
# Row_ID                                           1
# Order_ID                            CA-2016-152156
# Order_Date                     2016-11-08 00:00:00
# Ship_Date                      2016-11-11 00:00:00
# Ship_Mode                             Second Class
# Customer_ID                               CG-12520
# Customer_Name                          Claire Gute
# Segment                                   Consumer
# Country                              United States
# City                                     Henderson
# State                                     Kentucky
# Postal_Code                                  42420
# Region                                       South
# Product_ID                         FUR-BO-10001798
# Category                                 Furniture
# Sub-Category                             Bookcases
# Product_Name     Bush Somerset Collection Bookcase
# Sales                                       261.96
# ...

# %%
df['Order_ID']

#stores in series
# Out:
# 0       CA-2016-152156
# 1       CA-2016-152156
# 2       CA-2016-138688
# 3       US-2015-108966
# 4       US-2015-108966
#              ...
# 9989    CA-2014-110422
# 9990    CA-2017-121258
# 9991    CA-2017-121258
# 9992    CA-2017-121258
# 9993    CA-2017-119914
# Name: Order_ID, Length: 9994, dtype: object

# %%
#datastructure-type(), datatype-dtype
type(df['Order_ID'])
# Out:
# pandas.core.series.Series

# %%
type(df[['Order_ID']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['Order_ID', 'State']]
# Out:
#             Order_ID       State
# 0     CA-2016-152156    Kentucky
# 1     CA-2016-152156    Kentucky
# 2     CA-2016-138688  California
# 3     US-2015-108966     Florida
# 4     US-2015-108966     Florida
# ...              ...         ...
# 9989  CA-2014-110422     Florida
# 9990  CA-2017-121258  California
# 9991  CA-2017-121258  California
# 9992  CA-2017-121258  California
# 9993  CA-2017-119914  California
#
# [9994 rows x 2 columns]

# %%
#access the row
#i->index
df.iloc[-3:-1]
# Out:
#       Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# 9991    9992  CA-2017-121258  2/26/2017  03-03-2017  Standard Class
# 9992    9993  CA-2017-121258  2/26/2017  03-03-2017  Standard Class
#
#      Customer ID Customer Name   Segment        Country        City  ...  \
# 9991    DB-13060   Dave Brooks  Consumer  United States  Costa Mesa  ...
# 9992    DB-13060   Dave Brooks  Consumer  United States  Costa Mesa  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# 9991       92627    West  TEC-PH-10003645       Technology       Phones
# 9992       92627    West  OFF-PA-10004041  Office Supplies        Paper
#
#                                            Product Name    Sales  Quantity  \
# 9991                              Aastra 57i VoIP phone  258.576         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.600         4
#
#       Discount   Profit
# 9991       0.2  19.3932
# 9992       0.0  13.3200
#
# ...

# %%
df.iloc[5:]
# Out:
#       Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode  \
# 5          6  CA-2014-115812 2014-06-09        NaT  Standard Class
# 6          7  CA-2014-115812 2014-06-09        NaT  Standard Class
# 7          8  CA-2014-115812 2014-06-09        NaT  Standard Class
# 8          9  CA-2014-115812 2014-06-09        NaT  Standard Class
# 9         10  CA-2014-115812 2014-06-09        NaT  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422        NaT        NaT    Second Class
# 9990    9991  CA-2017-121258        NaT 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258        NaT 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258        NaT 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer_ID     Customer_Name   Segment        Country         City  ...  \
# 5       BH-11710   Brosina Hoffman  Consumer  United States  Los Angeles  ...
# ...

# %%
df.iloc[-1]
# Out:
# Row_ID                                                        9994
# Order_ID                                            CA-2017-119914
# Order_Date                                     2017-05-04 00:00:00
# Ship_Date                                      2017-05-09 00:00:00
# Ship_Mode                                             Second Class
# Customer_ID                                               CC-12220
# Customer_Name                                         Chris Cortes
# Segment                                                   Consumer
# Country                                              United States
# City                                                   Westminster
# State                                                   California
# Postal_Code                                                  92683
# Region                                                        West
# Product_ID                                         OFF-AP-10002684
# ...

# %%
df.iloc[-3:]
# Out:
#       Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode  \
# 9991    9992  CA-2017-121258        NaT 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258        NaT 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer_ID Customer_Name   Segment        Country         City  ...  \
# 9991    DB-13060   Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060   Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220  Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal_Code  Region       Product_ID         Category Sub-Category  \
# 9991       92627    West  TEC-PH-10003645       Technology       Phones
# 9992       92627    West  OFF-PA-10004041  Office Supplies        Paper
# 9993       92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product_Name    Sales  Quantity  \
# ...

# %%
df[['Order_ID', 'Order_Date','Ship_Date']].head()
# Out:
#          Order_ID Order_Date  Ship_Date
# 0  CA-2016-152156 2016-11-08 2016-11-11
# 1  CA-2016-152156 2016-11-08 2016-11-11
# 2  CA-2016-138688 2016-06-12        NaT
# 3  US-2015-108966 2015-10-11        NaT
# 4  US-2015-108966 2015-10-11        NaT

# %%
#univariate inspection
df['Region'].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
df['Region'].nunique()
# Out:
# 4

# %%
df['Order_ID'].nunique()
# Out:
# 5009

# %%
df[df["Region"] == "West"]
# Out:
#       Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode  \
# 2          3  CA-2016-138688 2016-06-12        NaT    Second Class
# 5          6  CA-2014-115812 2014-06-09        NaT  Standard Class
# 6          7  CA-2014-115812 2014-06-09        NaT  Standard Class
# 7          8  CA-2014-115812 2014-06-09        NaT  Standard Class
# 8          9  CA-2014-115812 2014-06-09        NaT  Standard Class
# ...      ...             ...        ...        ...             ...
# 9986    9987  CA-2016-125794        NaT 2016-10-03  Standard Class
# 9990    9991  CA-2017-121258        NaT 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258        NaT 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258        NaT 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer_ID    Customer_Name    Segment        Country         City  ...  \
# 2       DV-13045  Darrin Van Huff  Corporate  United States  Los Angeles  ...
# ...

# %%
(df["Region"] == "West").sum()
# Out:
# np.int64(3203)

# %%
#stores in another csv file
df[df["Region"] == "West"].to_csv("superstore_west.csv")

# %%
df[df["Region"] == "East"].to_csv("superstore_east.csv")

# %%
df[df["Region"] == "North"].to_csv("superstore_north.csv")

# %%
df[df["Region"] == "South"].to_csv("superstore_south.csv")

# %%
df1 = pd.read_csv("superstore_west.csv")
df2 = pd.read_csv("superstore_east.csv")
df3 = pd.read_csv("superstore_north.csv")
df4 = pd.read_csv("superstore_south.csv")

pd.concat([df1, df2, df3, df4])
# Out:
# /tmp/ipython-input-3599853858.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pd.concat([df1, df2, df3, df4])
#      Unnamed: 0 Row_ID        Order_ID  Order_Date   Ship_Date  \
# 0             2      3  CA-2016-138688  2016-06-12         NaN
# 1             5      6  CA-2014-115812  2014-06-09         NaN
# 2             6      7  CA-2014-115812  2014-06-09         NaN
# 3             7      8  CA-2014-115812  2014-06-09         NaN
# 4             8      9  CA-2014-115812  2014-06-09         NaN
# ...         ...    ...             ...         ...         ...
# 1615       9971   9972  CA-2015-103772         NaN  2015-07-02
# 1616       9980   9981  US-2015-151435  2015-09-06  2015-09-09
# ...
