# %% [markdown]
# # Pandas DataFrame – Exercise

# %% [markdown]
# ## 0. Setup

# %%
# import pandas
# import numpy as np
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. Create the dataset
#
#  create DataFrames
#
#            using list
#
#            using dictionary
#
# - `df_students`: student_id, name, program, marks
# - `df_scores`: student_id, attendance, internal_marks

# %%
#create list
course = ['VLSI', 'MVT', 'CYS']
type(course)
# Out:
# list

# %%
#convert to dataframe
df = pd.DataFrame(course)
df
# Out:
#       0
# 0  VLSI
# 1   MVT
# 2   CYS

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns = ['course']
df
# Out:
#   course
# 0   VLSI
# 1    MVT
# 2    CYS

# %% [markdown]
# ### Q1. Create a DataFrame using a list of lists
# Create `df_students` from a list-of-lists and set columns: `student_id`, `name`, `program`, `marks`.

# %%
# Create df_students using a list of lists
students = [
    [101, "Anu", "Cybersecurity", 85],
    [102, "Ravi", "Cybersecurity", 72],
    [103, "Meera", "Data Science", 91],
    [104, "Kiran", "Cybersecurity", 66],
    [105, "Sana", "AI", 78],
    [106, "Divya", "Data Science", 59],
]

# find the type of students
type(students)

# print the type


# convert the list in to dataframe
df = pd.DataFrame(students)
df
# add the column names to the dataframe
df.columns = ['student_id', 'name', 'program', 'marks']
# print the dataframe
df
#type(df)
df_students = pd.DataFrame(students, columns=["student_id", "name", "program", "marks"])
df_students
# List the column names
df.columns
# Out:
# Index(['student_id', 'name', 'program', 'marks'], dtype='object')

# %%
df_students[df_students['marks'] == 91]
# Out:
#    student_id   name       program  marks
# 2         103  Meera  Data Science     91

# %%
df_students.query('marks == 91')
# Out:
#    student_id   name       program  marks
# 2         103  Meera  Data Science     91

# %%
df_students.where(df_students['marks']>80)
#replace NaN into other message
df_students.where(df_students['marks']>80, other="Needs Improvement")
# Out:
#           student_id               name            program              marks
# 0                101                Anu      Cybersecurity                 85
# 1  Needs Improvement  Needs Improvement  Needs Improvement  Needs Improvement
# 2                103              Meera       Data Science                 91
# 3  Needs Improvement  Needs Improvement  Needs Improvement  Needs Improvement
# 4  Needs Improvement  Needs Improvement  Needs Improvement  Needs Improvement
# 5  Needs Improvement  Needs Improvement  Needs Improvement  Needs Improvement

# %% [markdown]
# ### Q2. Create a DataFrame using a dictionary
# Create `df_scores` from a dictionary with columns: `student_id`, `attendance`, `internal_marks`.

# %%
# Create df_scores using a dictionary
data = {
    "student_id": [101, 102, 103, 104, 105, 106],
    "attendance": [92, 85, 98, 70, 88, 76],
    "internal_marks": [40, 35, 45, 30, 38, 28],
}

# find the datatype of "data"
type(data)
# convert the dictionary into dataframe and store as df_scores
df_scores= pd.DataFrame(data)
df_scores
# df_scores =

# check the datatype
type(df_scores)
# print the dataframe
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### (Optional) Create a single working DataFrame
# Merge `df_students` and `df_scores` on `student_id` to form `df`.

# %%
# TODO: Merge into one DataFrame for convenience
# df = ...

df

# %% [markdown]
# ## 2. Data Inspection & Understanding Structure

# %% [markdown]
# ### Q3. Basic Data Inspection or Structural Data Inspection

# %%
# Find the first 3 records
df_students.head(3)

# Find the last 3 records
df_students.tail(3)
# Find the size of the dataframe
df_students.size
# Find the shape
df_students.shape
# Find the number of records
len(df_students)
# Find the number of columns
len(df_students.columns)
# Find the column names
df_students.columns
# Find the name of columns/ features
df_students.columns
# Find the index range
df_students.index
# Check the datatype
df_students.dtypes
# Out:
# student_id     int64
# name          object
# program       object
# marks          int64
# dtype: object

# %% [markdown]
# ### Q4. Missing Value Inspection
# Check if the dataset contains missing values; identify columns and counts.

# %%
#  Missing value inspection
# using info()
df_students.info()
# using isna()
df_students.isna()
# count how many null values
df_students.isna().sum()
#Explore
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   student_id  6 non-null      int64
#  1   name        6 non-null      object
#  2   program     6 non-null      object
#  3   marks       6 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 324.0+ bytes
# student_id    0
# name          0
# program       0
# marks         0
# dtype: int64

# %% [markdown]
# ### Q5. Data Type Reasoning
# Identify suitable dtypes (int/float/category). Convert applicable columns to category and explain why.

# %%
# Convert program to category


# Check the datatypes

# %% [markdown]
# ## 3. Indexing & Slicing

# %% [markdown]
# ### Q6. Column Indexing
# Select: (1) single column, (2) multiple columns.

# %%
# Extract the students name


# Extract the students name with their program details

# %% [markdown]
# ### Q7. Row Indexing
# Access a row using positional indexing, and a row using label-based indexing.

# %%
# Extract the first row and second row
# use iloc


# use loc


# Extract student_id with 103
# Out:
#    student_id   name       program  marks
# 2         103  Meera  Data Science     91

# %% [markdown]
# ### Q8. Index Manipulation

# %%
# Set the row index to student_id


# check the dataframe

# reset the index to default


# check the dataframe

# %% [markdown]
# ### Q9. Slicing Operations
# Slice: (1) range of rows, (2) specific rows+columns, (3) last two records for one column.

# %%
# slice range of row as per your choice
# using iloc

#using loc


# slice specific rows and columns


# Extract the last 5 marks

# %% [markdown]
# ## 4. Boolean Logic & Conditional Selection

# %% [markdown]
# ### Q10. Boolean Filtering

# %%
#  marks above a threshold (as per your choice); filter by program.

# %% [markdown]
# ### Q11. Comparison Operators
# Use comparison operators to filter by marks and attendance.

# %%
# extract the records where attendance is >=85 and the marks in the range 70 to 90.

# %% [markdown]
# ### Q12. Logical Operations (AND / OR / NOT)
# AND: multiple conditions; OR: either condition; NOT: exclude a category.

# %%
#  using and or not frame the questions as per your choice

# %% [markdown]
# ### Q13. isin() Operation

# %%
# program in list; student_id in list.

# %% [markdown]
# ## 5. Conditional Transformation

# %% [markdown]
# ### Q14. Using where()
# Replace marks below a threshold with a label or NaN; preserve original otherwise.

# %%
# df["marks_masked"] = df["marks"].where(df["marks"] >= 70, other=np.nan)
# OR replace with a string (creates object dtype)
# df["marks_flag"] = df["marks"].where(df["marks"] >= 70, other="Needs Improvement")
# df[["marks", "marks_masked"]].head()

# %% [markdown]
# ### Q15. Conditional Flag Column
# Create `eligible_for_exam`: True if attendance ≥ 75 else False. Count eligible vs non-eligible.

# %%
# df["eligible_for_exam"] = df["attendance"] >= 75
# df["eligible_for_exam"].value_counts()

# %%
#Condition: Cybersecurity students with marks ≥ 75
df[(df["program"] == "Cybersecurity") & (df["marks"] >= 75)]
df.query('program == "Cybersecurity" and marks >= 75')
df.where((df["program"] == "Cybersecurity") & (df["marks"] >= 75))

# %% [markdown]
# Use Boolean indexing when:
#
# you want maximum clarity/control
#
# you’re teaching fundamentals
#
# conditions are complex and you want explicit brackets
#
# Use query() when:
#
# you want readable filtering like SQL
#
# you’re doing exploratory analysis
#
# conditions are many and you prefer and/or/not
#
# Use where() when:
#
# you want to keep all rows but flag/mask invalid data
#
# you’re preparing data for cleaning
#
# you need structural consistency (same index/shape)

# %% [markdown]
# ## 6. Query-Based Filtering

# %% [markdown]
# ### Q16. Using query()
# Filter using query with multiple conditions; rewrite using boolean indexing; compare readability.

# %%
# TODO:
# q1 = df.query('program == "Cybersecurity" and marks >= 75')
# q1
# bool1 = df[(df["program"] == "Cybersecurity") & (df["marks"] >= 75)]
# bool1

# %% [markdown]
# ### Q17. Advanced query()
# Filter: not belonging to a specific program, and marks within a given range.

# %%
# TODO:
# df.query('program != "Data Science" and marks >= 70 and marks <= 90')

# %% [markdown]
# ## 7. Sorting & Ranking

# %% [markdown]
# ### Q18. Sorting Operations
# Sort by marks ascending/descending; sort by multiple columns.

# %%
# TODO:
# df.sort_values(by="marks", ascending=True)
# df.sort_values(by="marks", ascending=False)
# df.sort_values(by=["program", "marks"], ascending=[True, False])

# %% [markdown]
# ## 8. Statistical Operations

# %% [markdown]
# ### Q19. Basic Statistics
# Compute mean, median, std, min, max for marks and attendance.

# %%
# df[["marks", "attendance"]].mean()
# df[["marks", "attendance"]].median()
# df[["marks", "attendance"]].std()
# df[["marks", "attendance"]].min()
# df[["marks", "attendance"]].max()

# %% [markdown]
# ### Q20. Cumulative & Quantile Operations
# Compute cumsum of internal_marks; compute quartiles for marks.

# %%
# TODO:
# df["internal_cumsum"] = df["internal_marks"].cumsum()
# df["marks"].quantile([0.25, 0.50, 0.75])

# %% [markdown]
# ### Q21. Descriptive Summary
# Generate describe() summary and interpret key values.

# %%
# find the summary
