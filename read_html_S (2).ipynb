# %%
import pandas as pd

# %%
url1="http://www.fdic.gov/bank/individual/failed/banklist.html"
tables = pd.read_html(url1)
df = tables[0]
df
#type(df)
#df.shape
# Out:
#                                             Bank Name                City  \
# 0                   Metropolitan Capital Bank & Trust             Chicago
# 1                        The Santa Anna National Bank          Santa Anna
# 2                                Pulaski Savings Bank             Chicago
# 3                  The First National Bank of Lindsay             Lindsay
# 4               Republic First Bank dba Republic Bank        Philadelphia
# 5                                       Citizens Bank            Sac City
# 6                            Heartland Tri-State Bank             Elkhart
# 7                                 First Republic Bank       San Francisco
# 8                                      Signature Bank            New York
# 9                                 Silicon Valley Bank         Santa Clara
# 10                                  Almena State Bank              Almena
# 11                         First City Bank of Florida   Fort Walton Beach
# ...

# %%
url2 = "https://www.fdic.gov/bank-failures/failed-bank-list?pg=2"
tables1 = pd.read_html(url2)
df1 = tables1[0]
df1
#df1.shape
# Out:
#                                  Bank Name             City         State  \
# 0                   Harvest Community Bank       Pennsville    New Jersey
# 1                              Allied Bank         Mulberry      Arkansas
# 2             The Woodbury Banking Company         Woodbury       Georgia
# 3                   First CornerStone Bank  King of Prussia  Pennsylvania
# 4                       Trust Company Bank          Memphis     Tennessee
# 5               North Milwaukee State Bank        Milwaukee     Wisconsin
# 6                   Hometown National Bank         Longview    Washington
# 7                      The Bank of Georgia   Peachtree City       Georgia
# 8                             Premier Bank           Denver      Colorado
# 9                           Edgebrook Bank          Chicago      Illinois
# 10                              Doral Bank         San Juan   Puerto Rico
# 11       Capitol City Bank & Trust Company          Atlanta       Georgia
# ...

# %%
import pandas as pd

base = "https://www.fdic.gov/bank-failures/failed-bank-list"
all_pages = []

for pg in range(0, 50):  # 50 is a safe upper bound; we will stop when no table / no rows
    url = f"{base}?items_per_page=25&pg={pg}"
    try:
        tables = pd.read_html(url)
        if not tables:
            break
        page_df = tables[0]
        if page_df.empty:
            break
        all_pages.append(page_df)
    except ValueError:
        # read_html raises ValueError when it can't find tables
        break

df = pd.concat(all_pages, ignore_index=True).drop_duplicates()
print(df.shape)
df.head()
# Out:
# (573, 7)
#                                Bank Name          City         State   Cert  \
# 0      Metropolitan Capital Bank & Trust       Chicago      Illinois  57488
# 1           The Santa Anna National Bank    Santa Anna         Texas   5520
# 2                   Pulaski Savings Bank       Chicago      Illinois  28611
# 3     The First National Bank of Lindsay       Lindsay      Oklahoma   4134
# 4  Republic First Bank dba Republic Bank  Philadelphia  Pennsylvania  27332
#
#                Acquiring Institution      Closing Date  Fund  Sort ascending
# 0            First Independence Bank  January 30, 2026                 10550
# 1          Coleman County State Bank     June 27, 2025                 10549
# 2                    Millennium Bank  January 17, 2025                 10548
# 3             First Bank & Trust Co.  October 18, 2024                 10547
# 4  Fulton Bank, National Association    April 26, 2024                 10546

# %% [markdown]
# 05-02-2026

# %%
df.columns
# Out:
# Index(['Bank Name', 'City', 'State', 'Cert', 'Acquiring Institution',
#        'Closing Date', 'Fund  Sort ascending'],
#       dtype='object')

# %%
#find minimum value
df['Fund  Sort ascending'].min()
# Out:
# 4645

# %%
df['Fund  Sort ascending'].max()
# Out:
# 10550

# %%
df['Fund  Sort ascending'].cumsum()
# Out:
# 0        10550
# 1        21099
# 2        31647
# 3        42194
# 4        52740
#         ...
# 593    5737626
# 594    5742274
# 595    5746921
# 596    5751567
# 597    5756212
# Name: Fund  Sort ascending, Length: 573, dtype: int64

# %%
df['Fund  Sort ascending'].mean()
# Out:
# np.float64(10045.74520069808)

# %%
df['Fund  Sort ascending'].std()
# Out:
# 1107.550791901724

# %%
df['Fund  Sort ascending'].median()
# Out:
# 10262.0

# %%
df['Fund  Sort ascending'].mode()
# Out:
# 0       4645
# 1       4646
# 2       4647
# 3       4648
# 4       4649
#        ...
# 568    10546
# 569    10547
# 570    10548
# 571    10549
# 572    10550
# Name: Fund  Sort ascending, Length: 573, dtype: int64

# %%
df['Fund  Sort ascending'].cumprod()
# Out:
# 0                    10550
# 1                111291950
# 2            1173907488600
# 3        12381202282264200
# 4      1444950752791391888
#               ...
# 593                      0
# 594                      0
# 595                      0
# 596                      0
# 597                      0
# Name: Fund  Sort ascending, Length: 573, dtype: int64

# %%
df['Fund  Sort ascending'].cummin()
# Out:
# 0      10550
# 1      10549
# 2      10548
# 3      10547
# 4      10546
#        ...
# 593     4649
# 594     4648
# 595     4647
# 596     4646
# 597     4645
# Name: Fund  Sort ascending, Length: 573, dtype: int64

# %%
#find the range
df['Fund  Sort ascending'].max() - df['Fund  Sort ascending'].min()
# Out:
# 5905
