# %% [markdown]
# # import packages

# %%
# import pandas package
# import os package

import pandas as pd

# %%
import os

# %% [markdown]
# # Mount the drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Load the dataset

# %%
# load the credential_leak_demo.db into your google drive  - no code needed to do this step

# specify the directory path where the dataset is located
DIR = '/content/drive/MyDrive/Colab Notebooks/data'
datafile = 'credential_leak_demo_object.db'
filename = DIR+'/'+datafile

# %%
os.chdir(DIR)
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/data

# %%
# check the file is present or not
# !ls
# Out:
# 'alerts (1).json'		  eml		        superstore.csv
# 'alerts (2).json'		  incident_notes.txt    superstore.dbf
#  alerts.json			  ioc_feed.xml	        superstore_json.json
# 'auth_logs (1).csv'		  my_database.db        superstore_tsv.tsv
#  auth_logs.csv			  netflow.jsonl         superstore.txt
#  credential_leak_demo.db	  security_policy.yml   superstore_xls.xlsx
#  credential_leak_demo_object.db   soc_alerts.xlsx       web_access.log
#  dns_queries.tsv		  soc_dump.sql

# %%
# “Open (or create) the SQLite database file and keep the connection in conn
import sqlite3
conn = sqlite3.connect(filename)

# %% [markdown]
# Without a connection:
#
#     Python cannot read tables
#     Python cannot execute SQL queries
#     Python cannot convert tables to DataFrames
#     All database operations go through conn.

# %%
# !pwd
# Out:
# /content

# %%
# To explore the database
tables = pd.read_sql_query(
    "SELECT * FROM sqlite_master", conn
)
tables
# Out:
#     type                                name         tbl_name  rootpage  \
# 0  table                               users            users         2
# 1  index            sqlite_autoindex_users_1            users         3
# 2  table                     password_resets  password_resets         4
# 3  index  sqlite_autoindex_password_resets_1  password_resets         5
# 4  table                            sessions         sessions         6
# 5  index         sqlite_autoindex_sessions_1         sessions         7
# 6  table                            api_keys         api_keys         8
# 7  index         sqlite_autoindex_api_keys_1         api_keys         9
# 8  table                           audit_log        audit_log        10
# 9  index        sqlite_autoindex_audit_log_1        audit_log        11
#
#                                                  sql
# 0  CREATE TABLE users (\n  user_id TEXT PRIMARY K...
# 1                                               None
# 2  CREATE TABLE password_resets (\n  reset_id TEX...
# 3                                               None
# 4  CREATE TABLE sessions (\n  session_id TEXT PRI...
# 5                                               None
# 6  CREATE TABLE api_keys (\n  key_id TEXT PRIMARY...
# 7                                               None
# 8  CREATE TABLE audit_log (\n  event_id TEXT PRIM...
# 9                                               None

# %%
# Improvised
# To check all the tables in the database
tables = pd.read_sql_query(
    "SELECT * FROM sqlite_master WHERE type='table'", conn
)
tables
# Out:
#     type             name         tbl_name  rootpage  \
# 0  table            users            users         2
# 1  table  password_resets  password_resets         4
# 2  table         sessions         sessions         6
# 3  table         api_keys         api_keys         8
# 4  table        audit_log        audit_log        10
#
#                                                  sql
# 0  CREATE TABLE users (\n  user_id TEXT PRIMARY K...
# 1  CREATE TABLE password_resets (\n  reset_id TEX...
# 2  CREATE TABLE sessions (\n  session_id TEXT PRI...
# 3  CREATE TABLE api_keys (\n  key_id TEXT PRIMARY...
# 4  CREATE TABLE audit_log (\n  event_id TEXT PRIM...

# %%
# Improvised
tables = pd.read_sql_query(
    "SELECT name FROM sqlite_master WHERE type='table' ORDER BY name;",
    conn
)["name"].tolist()
tables
# Out:
# ['api_keys', 'audit_log', 'password_resets', 'sessions', 'users']

# %% [markdown]
#   SQLite stores tables and indexes as B-trees:
#
#       Root page → internal pages → leaf pages
#       Efficient searching, insertion, deletion
#       rootpage tells SQLite where to start traversal.

# %% [markdown]
# # Reading from the files

# %%
import sqlite3
conn = sqlite3.connect(filename)
df= pd.read_sql_query("SELECT * FROM users;", conn)
df
# Out:
#      user_id   username                  email  \
# 0          1  user00001  user00001@example.com
# 1          2  user00002   user00002@corp.local
# 2          3  user00003  user00003@example.com
# 3          4  user00004    user00004@mail.test
# 4          5  user00005   user00005@corp.local
# ...      ...        ...                    ...
# 5995    5996  user05996  user05996@example.com
# 5996    5997  user05997   user05997@corp.local
# 5997    5998  user05998   user05998@service.io
# 5998    5999  user05999   user05999@corp.local
# 5999    6000  user06000   user06000@corp.local
#
#                                           password_hash     password_salt  \
# 0     8d914e1cbb60b890c7399f2910cec96f8a5a8271363223...  bVrpoiVgRV5IfLBc
# 1     581e669218963490d73113876dde788b242cedd3bf6cfe...  SBvrjn9Wvgfygw2w
# 2     53a95abbb5fc355643afa051e051096dcccbcdad3332c5...  cQoXsf2o3gyrDO1x
# 3     8330d1676585fc69ec535bed89b7975db8b0a23501a8ff...  7OSJoRu1XXdo0cZu
# 4     f2889184f365ce51dd86bcdeaa4b03f74cd938666af404...  pVJIqVLB5LzxoiGF
# ...                                                 ...               ...
# 5995  b5eeefc9a6aa2ba2126f999db37b163ecd93919620f3f1...  1oU49MRWypWAO7hb
# 5996  7478fedc0c6703ab0313b84a47a1cee2a4dcbd89e595fe...  OnV3joXTYF6g8JuB
# 5997  e6ca07d767ad01a8ab27a52cbaf04e85a7e31f39db9367...  wbL15YRXMMA0sj8H
# 5998  1b92217c412b25b5a6443ff47c70dc43c3daf94b2918ec...  Jf0ZzGdH9pv6uTQE
# 5999  79ba122c6001903c87a94a0406748391f059d9261a0d24...  v5F33Jia3jFIVaOK
#
#          role mfa_enabled        last_login_utc           created_utc
# 0     student           1  2026-01-23T15:16:00Z  2026-01-23T15:16:00Z
# 1     student           0  2026-02-16T22:00:00Z  2026-01-02T22:00:00Z
# 2     student           0  2026-01-16T06:47:00Z  2025-12-23T06:47:00Z
# 3     student           0  2026-02-13T12:19:00Z  2026-01-28T12:19:00Z
# 4     student           0  2026-02-16T14:28:00Z  2026-01-12T14:28:00Z
# ...       ...         ...                   ...                   ...
# 5995  student           0                  None  2025-12-20T06:43:00Z
# 5996  student           0  2026-02-11T04:47:00Z  2026-01-29T04:47:00Z
# 5997  student           1  2026-02-07T19:15:00Z  2026-01-23T19:15:00Z
# 5998  student           1  2026-01-19T19:58:00Z  2025-12-20T19:58:00Z
# 5999    staff           0  2026-02-07T23:02:00Z  2025-12-21T23:02:00Z
#
# [6000 rows x 9 columns]

# %%
# Task:
# To check df is empty or not
df.empty
# Out:
# False

# %%
#To check the dimension
df.ndim
# Out:
# 2

# %%
# Task:
# find the datastructure of df
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Task:
# check the dataframe
df
# Out:
#      user_id   username                  email  \
# 0          1  user00001  user00001@example.com
# 1          2  user00002   user00002@corp.local
# 2          3  user00003  user00003@example.com
# 3          4  user00004    user00004@mail.test
# 4          5  user00005   user00005@corp.local
# ...      ...        ...                    ...
# 5995    5996  user05996  user05996@example.com
# 5996    5997  user05997   user05997@corp.local
# 5997    5998  user05998   user05998@service.io
# 5998    5999  user05999   user05999@corp.local
# 5999    6000  user06000   user06000@corp.local
#
#                                           password_hash     password_salt  \
# 0     8d914e1cbb60b890c7399f2910cec96f8a5a8271363223...  bVrpoiVgRV5IfLBc
# 1     581e669218963490d73113876dde788b242cedd3bf6cfe...  SBvrjn9Wvgfygw2w
# 2     53a95abbb5fc355643afa051e051096dcccbcdad3332c5...  cQoXsf2o3gyrDO1x
# 3     8330d1676585fc69ec535bed89b7975db8b0a23501a8ff...  7OSJoRu1XXdo0cZu
# 4     f2889184f365ce51dd86bcdeaa4b03f74cd938666af404...  pVJIqVLB5LzxoiGF
# ...                                                 ...               ...
# 5995  b5eeefc9a6aa2ba2126f999db37b163ecd93919620f3f1...  1oU49MRWypWAO7hb
# 5996  7478fedc0c6703ab0313b84a47a1cee2a4dcbd89e595fe...  OnV3joXTYF6g8JuB
# 5997  e6ca07d767ad01a8ab27a52cbaf04e85a7e31f39db9367...  wbL15YRXMMA0sj8H
# 5998  1b92217c412b25b5a6443ff47c70dc43c3daf94b2918ec...  Jf0ZzGdH9pv6uTQE
# 5999  79ba122c6001903c87a94a0406748391f059d9261a0d24...  v5F33Jia3jFIVaOK
#
#          role mfa_enabled        last_login_utc           created_utc
# 0     student           1  2026-01-23T15:16:00Z  2026-01-23T15:16:00Z
# 1     student           0  2026-02-16T22:00:00Z  2026-01-02T22:00:00Z
# 2     student           0  2026-01-16T06:47:00Z  2025-12-23T06:47:00Z
# 3     student           0  2026-02-13T12:19:00Z  2026-01-28T12:19:00Z
# 4     student           0  2026-02-16T14:28:00Z  2026-01-12T14:28:00Z
# ...       ...         ...                   ...                   ...
# 5995  student           0                  None  2025-12-20T06:43:00Z
# 5996  student           0  2026-02-11T04:47:00Z  2026-01-29T04:47:00Z
# 5997  student           1  2026-02-07T19:15:00Z  2026-01-23T19:15:00Z
# 5998  student           1  2026-01-19T19:58:00Z  2025-12-20T19:58:00Z
# 5999    staff           0  2026-02-07T23:02:00Z  2025-12-21T23:02:00Z
#
# [6000 rows x 9 columns]

# %%
# Task:
# Find the size
df.size
# Out:
# 54000

# %%
# Task:
# Find the total number of rows and columns
df.shape
# Out:
# (6000, 9)

# %%
# Task:
# Find the number of records
df.shape[0]
# Out:
# 6000

# %%
# Task:
# Find the total number of features / columns
df.shape[1]
# Out:
# 9

# %%
#Task:
# find the summary of the dataframe ie. column name + data type + non-null count
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   user_id         6000 non-null   object
#  1   username        6000 non-null   object
#  2   email           6000 non-null   object
#  3   password_hash   6000 non-null   object
#  4   password_salt   6000 non-null   object
#  5   role            6000 non-null   object
#  6   mfa_enabled     6000 non-null   object
#  7   last_login_utc  5369 non-null   object
#  8   created_utc     6000 non-null   object
# dtypes: object(9)
# memory usage: 422.0+ KB

# %%
#Find summary statistics
df.describe()
# Out:
#        user_id   username                 email  \
# count     6000       6000                  6000
# unique    6000       6000                  6000
# top       5984  user05984  user05984@service.io
# freq         1          1                     1
#
#                                             password_hash     password_salt  \
# count                                                6000              6000
# unique                                               6000              6000
# top     b20ac7ef38dbfefc99805da85a81478863ef8c39ce0199...  mav4wGE9zJifpmHn
# freq                                                    1                 1
#
#            role mfa_enabled        last_login_utc           created_utc
# count      6000        6000                  5369                  6000
# unique        4           2                  5269                  5783
# top     student           0  2026-01-29T18:18:00Z  2025-12-10T03:41:00Z
# freq       4223        3879                     3                     3

# %%
# find the datatypes
df.dtypes
# Out:
# user_id           object
# username          object
# email             object
# password_hash     object
# password_salt     object
# role              object
# mfa_enabled       object
# last_login_utc    object
# created_utc       object
# dtype: object

# %%
#generate a summary of descriptive statistics for non-numeric
df.describe()
# Out:
#        user_id   username                 email  \
# count     6000       6000                  6000
# unique    6000       6000                  6000
# top       5984  user05984  user05984@service.io
# freq         1          1                     1
#
#                                             password_hash     password_salt  \
# count                                                6000              6000
# unique                                               6000              6000
# top     b20ac7ef38dbfefc99805da85a81478863ef8c39ce0199...  mav4wGE9zJifpmHn
# freq                                                    1                 1
#
#            role mfa_enabled        last_login_utc           created_utc
# count      6000        6000                  5369                  6000
# unique        4           2                  5269                  5783
# top     student           0  2026-01-29T18:18:00Z  2025-12-10T03:41:00Z
# freq       4223        3879                     3                     3

# %%
#Task:
#check is the any null values
df.isna()
# Out:
#       user_id  username  email  password_hash  password_salt   role  \
# 0       False     False  False          False          False  False
# 1       False     False  False          False          False  False
# 2       False     False  False          False          False  False
# 3       False     False  False          False          False  False
# 4       False     False  False          False          False  False
# ...       ...       ...    ...            ...            ...    ...
# 5995    False     False  False          False          False  False
# 5996    False     False  False          False          False  False
# 5997    False     False  False          False          False  False
# 5998    False     False  False          False          False  False
# 5999    False     False  False          False          False  False
#
#       mfa_enabled  last_login_utc  created_utc
# 0           False           False        False
# 1           False           False        False
# 2           False           False        False
# 3           False           False        False
# 4           False           False        False
# ...           ...             ...          ...
# 5995        False            True        False
# 5996        False           False        False
# 5997        False           False        False
# 5998        False           False        False
# 5999        False           False        False
#
# [6000 rows x 9 columns]

# %%
# Task:
# Check not null values
df.notna()
# Out:
#       user_id  username  email  password_hash  password_salt  role  \
# 0        True      True   True           True           True  True
# 1        True      True   True           True           True  True
# 2        True      True   True           True           True  True
# 3        True      True   True           True           True  True
# 4        True      True   True           True           True  True
# ...       ...       ...    ...            ...            ...   ...
# 5995     True      True   True           True           True  True
# 5996     True      True   True           True           True  True
# 5997     True      True   True           True           True  True
# 5998     True      True   True           True           True  True
# 5999     True      True   True           True           True  True
#
#       mfa_enabled  last_login_utc  created_utc
# 0            True            True         True
# 1            True            True         True
# 2            True            True         True
# 3            True            True         True
# 4            True            True         True
# ...           ...             ...          ...
# 5995         True           False         True
# 5996         True            True         True
# 5997         True            True         True
# 5998         True            True         True
# 5999         True            True         True
#
# [6000 rows x 9 columns]

# %%
# Task:
#Total non-null counts for each column
df.notna().sum()
# Out:
# user_id           6000
# username          6000
# email             6000
# password_hash     6000
# password_salt     6000
# role              6000
# mfa_enabled       6000
# last_login_utc    5369
# created_utc       6000
# dtype: int64

# %%
#Which columns contain missing values
df.isna().any()
# Out:
# user_id           False
# username          False
# email             False
# password_hash     False
# password_salt     False
# role              False
# mfa_enabled       False
# last_login_utc     True
# created_utc       False
# dtype: bool

# %%
# Task:
# Count missing values
df.isna().sum()
# Out:
# user_id             0
# username            0
# email               0
# password_hash       0
# password_salt       0
# role                0
# mfa_enabled         0
# last_login_utc    631
# created_utc         0
# dtype: int64

# %%
# Task:
# Find the first 5 records
df.head()
# Out:
#   user_id   username                  email  \
# 0       1  user00001  user00001@example.com
# 1       2  user00002   user00002@corp.local
# 2       3  user00003  user00003@example.com
# 3       4  user00004    user00004@mail.test
# 4       5  user00005   user00005@corp.local
#
#                                        password_hash     password_salt  \
# 0  8d914e1cbb60b890c7399f2910cec96f8a5a8271363223...  bVrpoiVgRV5IfLBc
# 1  581e669218963490d73113876dde788b242cedd3bf6cfe...  SBvrjn9Wvgfygw2w
# 2  53a95abbb5fc355643afa051e051096dcccbcdad3332c5...  cQoXsf2o3gyrDO1x
# 3  8330d1676585fc69ec535bed89b7975db8b0a23501a8ff...  7OSJoRu1XXdo0cZu
# 4  f2889184f365ce51dd86bcdeaa4b03f74cd938666af404...  pVJIqVLB5LzxoiGF
#
#       role mfa_enabled        last_login_utc           created_utc
# 0  student           1  2026-01-23T15:16:00Z  2026-01-23T15:16:00Z
# 1  student           0  2026-02-16T22:00:00Z  2026-01-02T22:00:00Z
# 2  student           0  2026-01-16T06:47:00Z  2025-12-23T06:47:00Z
# 3  student           0  2026-02-13T12:19:00Z  2026-01-28T12:19:00Z
# 4  student           0  2026-02-16T14:28:00Z  2026-01-12T14:28:00Z

# %%
# Task:
# Find the first 10 records
df.head(10)
# Out:
#   user_id   username                  email  \
# 0       1  user00001  user00001@example.com
# 1       2  user00002   user00002@corp.local
# 2       3  user00003  user00003@example.com
# 3       4  user00004    user00004@mail.test
# 4       5  user00005   user00005@corp.local
# 5       6  user00006  user00006@example.com
# 6       7  user00007   user00007@corp.local
# 7       8  user00008   user00008@service.io
# 8       9  user00009  user00009@example.com
# 9      10  user00010  user00010@example.com
#
#                                        password_hash     password_salt  \
# 0  8d914e1cbb60b890c7399f2910cec96f8a5a8271363223...  bVrpoiVgRV5IfLBc
# 1  581e669218963490d73113876dde788b242cedd3bf6cfe...  SBvrjn9Wvgfygw2w
# 2  53a95abbb5fc355643afa051e051096dcccbcdad3332c5...  cQoXsf2o3gyrDO1x
# 3  8330d1676585fc69ec535bed89b7975db8b0a23501a8ff...  7OSJoRu1XXdo0cZu
# 4  f2889184f365ce51dd86bcdeaa4b03f74cd938666af404...  pVJIqVLB5LzxoiGF
# 5  8fc5e174e1ba391a10e72f60c2ed6c9fc4d8b28b8c6800...  RUhR4IWrXPvhsBkD
# 6  5ffe482fbdddeef2a9c45ca7e97c6918a5390ea1154fa6...  xWkI9X7H6aMuFbh7
# 7  44cef8e1ebedd1ced27557fd814c5cfd14d996b367273b...  XiiQE8JkqH3MB9n7
# 8  d647ee8645b5faf2aea068260be22c0a4559d90980e118...  LJoLoaeTOdoe5c3v
# 9  85ad4d23a799be4ac733105fa0777019d5cce3dbaa403a...  gQBwBAD3UdRPPgdz
#
#       role mfa_enabled        last_login_utc           created_utc
# 0  student           1  2026-01-23T15:16:00Z  2026-01-23T15:16:00Z
# 1  student           0  2026-02-16T22:00:00Z  2026-01-02T22:00:00Z
# 2  student           0  2026-01-16T06:47:00Z  2025-12-23T06:47:00Z
# 3  student           0  2026-02-13T12:19:00Z  2026-01-28T12:19:00Z
# 4  student           0  2026-02-16T14:28:00Z  2026-01-12T14:28:00Z
# 5    staff           1  2026-02-09T03:48:00Z  2026-01-28T03:48:00Z
# 6  student           0                  None  2025-12-07T07:11:00Z
# 7    staff           0  2026-01-13T13:33:00Z  2025-12-23T13:33:00Z
# 8  student           0  2026-01-25T01:13:00Z  2026-01-13T01:13:00Z
# 9  student           0  2026-01-11T20:40:00Z  2025-12-07T20:40:00Z

# %%
# Task:
# Find the last 15 records
df.tail(15)
# Out:
#      user_id   username                  email  \
# 5985    5986  user05986   user05986@corp.local
# 5986    5987  user05987   user05987@service.io
# 5987    5988  user05988   user05988@corp.local
# 5988    5989  user05989   user05989@corp.local
# 5989    5990  user05990    user05990@mail.test
# 5990    5991  user05991  user05991@example.com
# 5991    5992  user05992   user05992@corp.local
# 5992    5993  user05993  user05993@example.com
# 5993    5994  user05994   user05994@corp.local
# 5994    5995  user05995    user05995@mail.test
# 5995    5996  user05996  user05996@example.com
# 5996    5997  user05997   user05997@corp.local
# 5997    5998  user05998   user05998@service.io
# 5998    5999  user05999   user05999@corp.local
# 5999    6000  user06000   user06000@corp.local
#
#                                           password_hash     password_salt  \
# 5985  166b9a72179a3e8d7a651274910c472cf570f9cad2ef00...  UPsUsHJSpF7wT0fX
# 5986  faf9b431b557b860e38e72fd20932b9ba95f441c691ed8...  EY3QQcqFsDhYQitR
# 5987  b64c1135e7c89576a8a78e6d1474e5c00af32f26f322be...  eNcAHjkaCw8XGssW
# 5988  4ce06918948c8c017609502fe187a50374796ad3e28d49...  t44KM8PT2znavuyP
# 5989  218a97c330365c53e365fd9317a6c27e246c0031582cb2...  ZLcx5jXqswBjGoEp
# 5990  373ee42c1d25579da009006d5cb26474f4d070d25b545d...  ypU8tz9OVmMKHUOh
# 5991  5df2500f1ad01293301895dd26174c3f57d1cd03c81120...  e33rXnzuV7dpxa2s
# 5992  69a441e681264a10318f46518b504c122540652f51822c...  6DnEvqDBZPXbRoIo
# 5993  228073cab25cb05d2177a26b59856ba91539c6bda64754...  IxYoPicJgifpf2w8
# 5994  b2ff31419a2969d041931e1d18992093ac4d4260b78f14...  fBDMbGSQux6wVaD8
# 5995  b5eeefc9a6aa2ba2126f999db37b163ecd93919620f3f1...  1oU49MRWypWAO7hb
# 5996  7478fedc0c6703ab0313b84a47a1cee2a4dcbd89e595fe...  OnV3joXTYF6g8JuB
# 5997  e6ca07d767ad01a8ab27a52cbaf04e85a7e31f39db9367...  wbL15YRXMMA0sj8H
# 5998  1b92217c412b25b5a6443ff47c70dc43c3daf94b2918ec...  Jf0ZzGdH9pv6uTQE
# 5999  79ba122c6001903c87a94a0406748391f059d9261a0d24...  v5F33Jia3jFIVaOK
#
#          role mfa_enabled        last_login_utc           created_utc
# 5985  student           0  2026-02-08T17:20:00Z  2026-01-18T17:20:00Z
# 5986  student           1  2026-01-14T00:09:00Z  2026-01-14T00:09:00Z
# 5987    staff           1                  None  2026-01-01T12:18:00Z
# 5988    staff           1                  None  2026-01-06T08:58:00Z
# 5989  student           0  2026-02-13T06:01:00Z  2025-12-25T06:01:00Z
# 5990  student           0  2026-02-22T16:44:00Z  2026-01-23T16:44:00Z
# 5991  student           0  2026-02-09T19:58:00Z  2026-01-07T19:58:00Z
# 5992  student           1  2026-03-01T05:51:00Z  2026-01-23T05:51:00Z
# 5993  student           1  2025-12-16T11:57:00Z  2025-12-09T11:57:00Z
# 5994  student           1  2026-01-14T07:14:00Z  2025-12-05T07:14:00Z
# 5995  student           0                  None  2025-12-20T06:43:00Z
# 5996  student           0  2026-02-11T04:47:00Z  2026-01-29T04:47:00Z
# 5997  student           1  2026-02-07T19:15:00Z  2026-01-23T19:15:00Z
# 5998  student           1  2026-01-19T19:58:00Z  2025-12-20T19:58:00Z
# 5999    staff           0  2026-02-07T23:02:00Z  2025-12-21T23:02:00Z

# %%
# Task:
# Extract 15th record
df.iloc[15]
# Out:
# user_id                                                          16
# username                                                  user00016
# email                                            user00016@univ.edu
# password_hash     213fbf7dd2291db34d29062cc006984aabb98a815a20f9...
# password_salt                                      Jahe84S5jIc1xLJj
# role                                                        student
# mfa_enabled                                                       1
# last_login_utc                                 2026-01-14T08:33:00Z
# created_utc                                    2025-12-10T08:33:00Z
# Name: 15, dtype: object

# %%
# Task:
# Extract 10th record to 15th record``
df.iloc[10:16]
# Out:
#    user_id   username                  email  \
# 10      11  user00011  user00011@example.com
# 11      12  user00012   user00012@corp.local
# 12      13  user00013   user00013@corp.local
# 13      14  user00014  user00014@example.com
# 14      15  user00015   user00015@service.io
# 15      16  user00016     user00016@univ.edu
#
#                                         password_hash     password_salt  \
# 10  2216a7d8714ce9cb290ac1c5af3028c16b33e2a59842cf...  dPI1af7W2pkAFEn3
# 11  bf349ad9487b3ccd28b1d3d06cc6221c7b4396bb0ab0c0...  msn9dLVIdVuddLEG
# 12  d8a1903e48f3eafb66e8064173a8b4d4d2dcff0cd4977c...  LMcNfAQLKHu7qnQT
# 13  046167458007fa4debdb82c3c997f28b50cf5cbadfac15...  eInGqi7w4e4pxskC
# 14  412dbefbe75a364345e656a0b8b3723db94dcbea5db90b...  jrsMnTvnRO2qGFq5
# 15  213fbf7dd2291db34d29062cc006984aabb98a815a20f9...  Jahe84S5jIc1xLJj
#
#        role mfa_enabled        last_login_utc           created_utc
# 10  student           0  2026-02-20T14:05:00Z  2026-01-20T14:05:00Z
# 11  student           0  2026-02-11T18:03:00Z  2026-01-06T18:03:00Z
# 12    staff           1                  None  2026-01-26T12:56:00Z
# 13  student           0  2025-12-19T05:21:00Z  2025-12-13T05:21:00Z
# 14  student           0  2026-01-19T16:58:00Z  2025-12-15T16:58:00Z
# 15  student           1  2026-01-14T08:33:00Z  2025-12-10T08:33:00Z

# %%
# Task:
# randomly select one record
df.sample()
# Out:
#      user_id   username                email  \
# 5090    5091  user05091  user05091@mail.test
#
#                                           password_hash     password_salt  \
# 5090  77812019ed1f85a59d8f5c5f16ce7d60f4eeca591fb9ca...  engYXcgY06a2Vhda
#
#          role mfa_enabled        last_login_utc           created_utc
# 5090  auditor           0  2026-02-10T15:49:00Z  2026-01-11T15:49:00Z

# %%
# Task:
# pick randomly 10 records
df.sample(10)
# Out:
#      user_id   username                  email  \
# 5210    5211  user05211   user05211@service.io
# 2465    2466  user02466  user02466@example.com
# 3861    3862  user03862   user03862@service.io
# 660      661  user00661  user00661@example.com
# 1701    1702  user01702     user01702@univ.edu
# 5655    5656  user05656   user05656@corp.local
# 336      337  user00337  user00337@example.com
# 2695    2696  user02696    user02696@mail.test
# 1547    1548  user01548    user01548@mail.test
# 2471    2472  user02472  user02472@example.com
#
#                                           password_hash     password_salt  \
# 5210  ccc3fd121f0870280de43dc092670ac1d270e1473682de...  5ziwfTleHP5djsau
# 2465  21387b99832e2b9a3ce516a7fd0667d124647487b2fd33...  64FmRU6i096dnfQa
# 3861  4faaba289db4b154001ad295cbcc20d8c43f157bd741bc...  GPX4NnrVuFy81sKt
# 660   b3498f19c2653f79dfd386f724606217f59a2da5d9ee16...  RW5TCaVRfuLX66xS
# 1701  18d26d987ede0f3aba35d6b66a8e9c8929409662c93443...  J5RJR4SAKGV137S5
# 5655  fa083d5dc29eb22f038b382e522cdb241ed6293c77f628...  RFJRGThNghvug9Mj
# 336   8f60fbfcd91d64b9145d5f25b95ed6cd489f3dff7edaa5...  9xk8KhaTHBX67D0R
# 2695  c564fae50e153af0638952ce4d73505da3ac2e8aaafa2e...  Jgnfid9w4MpdJKHN
# 1547  92cf4b3adbdbd69f5c1ce856c76df645892d0872d5e980...  wL3VGXFLU6idBYjo
# 2471  9f70df58874195f9c5da14a080d61437e48e430f23d402...  wVm7Q6GOmR4tJ01P
#
#          role mfa_enabled        last_login_utc           created_utc
# 5210  student           1  2026-01-11T17:58:00Z  2026-01-03T17:58:00Z
# 2465    staff           0  2026-02-26T06:12:00Z  2026-01-16T06:12:00Z
# 3861    staff           0  2026-01-26T13:56:00Z  2025-12-08T13:56:00Z
# 660     staff           0  2026-02-15T11:36:00Z  2026-01-15T11:36:00Z
# 1701  student           0  2026-01-18T18:06:00Z  2026-01-09T18:06:00Z
# 5655  student           0  2026-01-14T16:48:00Z  2025-12-30T16:48:00Z
# 336     staff           0  2026-02-16T06:12:00Z  2026-01-09T06:12:00Z
# 2695  student           0  2026-01-29T02:29:00Z  2025-12-29T02:29:00Z
# 1547    staff           0  2026-01-16T14:22:00Z  2025-12-10T14:22:00Z
# 2471  student           0  2026-01-02T04:45:00Z  2025-12-31T04:45:00Z

# %%
# Task:
# Extract the column 'country'
df['email']
# Out:
# 0       user00001@example.com
# 1        user00002@corp.local
# 2       user00003@example.com
# 3         user00004@mail.test
# 4        user00005@corp.local
#                 ...
# 5995    user05996@example.com
# 5996     user05997@corp.local
# 5997     user05998@service.io
# 5998     user05999@corp.local
# 5999     user06000@corp.local
# Name: email, Length: 6000, dtype: object

# %%
# Task:
# swaps the rows and columns
df.swapaxes(0, 1)
#df.T
#df.transpose()
# Note: it is used when we have more features
# Out:
# /tmp/ipython-input-1379086106.py:3: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   df.swapaxes(0, 1)
#                                                              0     \
# user_id                                                         1
# username                                                user00001
# email                                       user00001@example.com
# password_hash   8d914e1cbb60b890c7399f2910cec96f8a5a8271363223...
# password_salt                                    bVrpoiVgRV5IfLBc
# role                                                      student
# mfa_enabled                                                     1
# last_login_utc                               2026-01-23T15:16:00Z
# created_utc                                  2026-01-23T15:16:00Z
#
#                                                              1     \
# user_id                                                         2
# username                                                user00002
# email                                        user00002@corp.local
# password_hash   581e669218963490d73113876dde788b242cedd3bf6cfe...
# password_salt                                    SBvrjn9Wvgfygw2w
# role                                                      student
# mfa_enabled                                                     0
# last_login_utc                               2026-02-16T22:00:00Z
# created_utc                                  2026-01-02T22:00:00Z
#
#                                                              2     \
# user_id                                                         3
# username                                                user00003
# email                                       user00003@example.com
# password_hash   53a95abbb5fc355643afa051e051096dcccbcdad3332c5...
# password_salt                                    cQoXsf2o3gyrDO1x
# role                                                      student
# mfa_enabled                                                     0
# last_login_utc                               2026-01-16T06:47:00Z
# created_utc                                  2025-12-23T06:47:00Z
#
#                                                              3     \
# user_id                                                         4
# username                                                user00004
# email                                         user00004@mail.test
# password_hash   8330d1676585fc69ec535bed89b7975db8b0a23501a8ff...
# password_salt                                    7OSJoRu1XXdo0cZu
# role                                                      student
# mfa_enabled                                                     0
# last_login_utc                               2026-02-13T12:19:00Z
# created_utc                                  2026-01-28T12:19:00Z
#
#                                                              4     \
# user_id                                                         5
# username                                                user00005
# email                                        user00005@corp.local
# password_hash   f2889184f365ce51dd86bcdeaa4b03f74cd938666af404...
# password_salt                                    pVJIqVLB5LzxoiGF
# role                                                      student
# mfa_enabled                                                     0
# last_login_utc                               2026-02-16T14:28:00Z
# created_utc                                  2026-01-12T14:28:00Z
#
#                                                              5     \
# user_id                                                         6
# username                                                user00006
# email                                       user00006@example.com
# password_hash   8fc5e174e1ba391a10e72f60c2ed6c9fc4d8b28b8c6800...
# password_salt                                    RUhR4IWrXPvhsBkD
# role                                                        staff
# mfa_enabled                                                     1
# last_login_utc                               2026-02-09T03:48:00Z
# created_utc                                  2026-01-28T03:48:00Z
#
#                                                              6     \
# user_id                                                         7
# username                                                user00007
# email                                        user00007@corp.local
# password_hash   5ffe482fbdddeef2a9c45ca7e97c6918a5390ea1154fa6...
# password_salt                                    xWkI9X7H6aMuFbh7
# role                                                      student
# mfa_enabled                                                     0
# last_login_utc                                               None
# created_utc                                  2025-12-07T07:11:00Z
#
#                                                              7     \
# user_id                                                         8
# username                                                user00008
# email                                        user00008@service.io
# password_hash   44cef8e1ebedd1ced27557fd814c5cfd14d996b367273b...
# password_salt                                    XiiQE8JkqH3MB9n7
# role                                                        staff
# mfa_enabled                                                     0
# last_login_utc                               2026-01-13T13:33:00Z
# created_utc                                  2025-12-23T13:33:00Z
#
#                                                              8     \
# user_id                                                         9
# username                                                user00009
# email                                       user00009@example.com
# password_hash   d647ee8645b5faf2aea068260be22c0a4559d90980e118...
# password_salt                                    LJoLoaeTOdoe5c3v
# role                                                      student
# mfa_enabled                                                     0
# last_login_utc                               2026-01-25T01:13:00Z
# created_utc                                  2026-01-13T01:13:00Z
#
#                                                              9     ...  \
# user_id                                                        10  ...
# username                                                user00010  ...
# email                                       user00010@example.com  ...
# password_hash   85ad4d23a799be4ac733105fa0777019d5cce3dbaa403a...  ...
# password_salt                                    gQBwBAD3UdRPPgdz  ...
# role                                                      student  ...
# mfa_enabled                                                     0  ...
# last_login_utc                               2026-01-11T20:40:00Z  ...
# created_utc                                  2025-12-07T20:40:00Z  ...
#
#                                                              5990  \
# user_id                                                      5991
# username                                                user05991
# email                                       user05991@example.com
# password_hash   373ee42c1d25579da009006d5cb26474f4d070d25b545d...
# password_salt                                    ypU8tz9OVmMKHUOh
# role                                                      student
# mfa_enabled                                                     0
# last_login_utc                               2026-02-22T16:44:00Z
# created_utc                                  2026-01-23T16:44:00Z
#
#                                                              5991  \
# user_id                                                      5992
# username                                                user05992
# email                                        user05992@corp.local
# password_hash   5df2500f1ad01293301895dd26174c3f57d1cd03c81120...
# password_salt                                    e33rXnzuV7dpxa2s
# role                                                      student
# mfa_enabled                                                     0
# last_login_utc                               2026-02-09T19:58:00Z
# created_utc                                  2026-01-07T19:58:00Z
#
#                                                              5992  \
# user_id                                                      5993
# username                                                user05993
# email                                       user05993@example.com
# password_hash   69a441e681264a10318f46518b504c122540652f51822c...
# password_salt                                    6DnEvqDBZPXbRoIo
# role                                                      student
# mfa_enabled                                                     1
# last_login_utc                               2026-03-01T05:51:00Z
# created_utc                                  2026-01-23T05:51:00Z
#
#                                                              5993  \
# user_id                                                      5994
# username                                                user05994
# email                                        user05994@corp.local
# password_hash   228073cab25cb05d2177a26b59856ba91539c6bda64754...
# password_salt                                    IxYoPicJgifpf2w8
# role                                                      student
# mfa_enabled                                                     1
# last_login_utc                               2025-12-16T11:57:00Z
# created_utc                                  2025-12-09T11:57:00Z
#
#                                                              5994  \
# user_id                                                      5995
# username                                                user05995
# email                                         user05995@mail.test
# password_hash   b2ff31419a2969d041931e1d18992093ac4d4260b78f14...
# password_salt                                    fBDMbGSQux6wVaD8
# role                                                      student
# mfa_enabled                                                     1
# last_login_utc                               2026-01-14T07:14:00Z
# created_utc                                  2025-12-05T07:14:00Z
#
#                                                              5995  \
# user_id                                                      5996
# username                                                user05996
# email                                       user05996@example.com
# password_hash   b5eeefc9a6aa2ba2126f999db37b163ecd93919620f3f1...
# password_salt                                    1oU49MRWypWAO7hb
# role                                                      student
# mfa_enabled                                                     0
# last_login_utc                                               None
# created_utc                                  2025-12-20T06:43:00Z
#
#                                                              5996  \
# user_id                                                      5997
# username                                                user05997
# email                                        user05997@corp.local
# password_hash   7478fedc0c6703ab0313b84a47a1cee2a4dcbd89e595fe...
# password_salt                                    OnV3joXTYF6g8JuB
# role                                                      student
# mfa_enabled                                                     0
# last_login_utc                               2026-02-11T04:47:00Z
# created_utc                                  2026-01-29T04:47:00Z
#
#                                                              5997  \
# user_id                                                      5998
# username                                                user05998
# email                                        user05998@service.io
# password_hash   e6ca07d767ad01a8ab27a52cbaf04e85a7e31f39db9367...
# password_salt                                    wbL15YRXMMA0sj8H
# role                                                      student
# mfa_enabled                                                     1
# last_login_utc                               2026-02-07T19:15:00Z
# created_utc                                  2026-01-23T19:15:00Z
#
#                                                              5998  \
# user_id                                                      5999
# username                                                user05999
# email                                        user05999@corp.local
# password_hash   1b92217c412b25b5a6443ff47c70dc43c3daf94b2918ec...
# password_salt                                    Jf0ZzGdH9pv6uTQE
# role                                                      student
# mfa_enabled                                                     1
# last_login_utc                               2026-01-19T19:58:00Z
# created_utc                                  2025-12-20T19:58:00Z
#
#                                                              5999
# user_id                                                      6000
# username                                                user06000
# email                                        user06000@corp.local
# password_hash   79ba122c6001903c87a94a0406748391f059d9261a0d24...
# password_salt                                    v5F33Jia3jFIVaOK
# role                                                        staff
# mfa_enabled                                                     0
# last_login_utc                               2026-02-07T23:02:00Z
# created_utc                                  2025-12-21T23:02:00Z
#
# [9 rows x 6000 columns]

# %%
# Task: list all the column name
df.columns
# Out:
# Index(['user_id', 'username', 'email', 'password_hash', 'password_salt',
#        'role', 'mfa_enabled', 'last_login_utc', 'created_utc'],
#       dtype='object')

# %%
# list all the datatypes
df.dtypes
# Out:
# user_id           object
# username          object
# email             object
# password_hash     object
# password_salt     object
# role              object
# mfa_enabled       object
# last_login_utc    object
# created_utc       object
# dtype: object

# %%
df.sample()
# Out:
#      user_id   username                email  \
# 3326    3327  user03327  user03327@mail.test
#
#                                           password_hash     password_salt  \
# 3326  3902e2c01b03e4a5dacbac3bb8445a4742a94cfa424bc6...  uxj8McOamwN3kOb9
#
#          role mfa_enabled        last_login_utc           created_utc
# 3326  student           0  2026-02-22T19:52:00Z  2026-01-07T19:52:00Z

# %% [markdown]
# Pandas Datatypes
#     - Numeric
#           - int
#           - float
#
#     - String
#        - fixed values
#           - category
#        - not fixed values
#           - object
#
#     - Boolean
#         - bool
#
#     - Datetime
#           - datetime
#           - timedelta

# %%
# change a column’s data type to the corresponding (appropriate) datatype
# step : Inspect -->   Decide --> Convert  --> Verify
# user_id

# %%
df.columns
# Out:
# Index(['user_id', 'username', 'email', 'password_hash', 'password_salt',
#        'role', 'mfa_enabled', 'last_login_utc', 'created_utc'],
#       dtype='object')

# %%
# change user_id to int
df['user_id'] = df['user_id'].astype('int')

# %%
df.dtypes
# Out:
# user_id            int64
# username          object
# email             object
# password_hash     object
# password_salt     object
# role              object
# mfa_enabled       object
# last_login_utc    object
# created_utc       object
# dtype: object

# %%
# role
df['role'] = df['role'].astype('category')

# %%
df.dtypes
# Out:
# user_id                         int64
# username                       object
# email                          object
# password_hash                  object
# password_salt                  object
# role                         category
# mfa_enabled                      bool
# last_login_utc    datetime64[ns, UTC]
# created_utc       datetime64[ns, UTC]
# dtype: object

# %%
df["mfa_enabled"] = df["mfa_enabled"].astype(bool)
df["mfa_enabled"]
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 5995    True
# 5996    True
# 5997    True
# 5998    True
# 5999    True
# Name: mfa_enabled, Length: 6000, dtype: bool

# %%
#mfa_enabled
df["mfa_enabled"] = df["mfa_enabled"].map({"1": True, "0": False})

# %%
# if it mixed pattern
df["mfa_enabled"] = df["mfa_enabled"].str.lower().map({
    "1": True, "0": False,
    "yes": True, "no": False,
    "true": True, "false": False
})
df["mfa_enabled"]
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 5995    NaN
# 5996    NaN
# 5997    NaN
# 5998    NaN
# 5999    NaN
# Name: mfa_enabled, Length: 6000, dtype: object

# %%
# last_login_utc
df["last_login_utc"] = pd.to_datetime(df["last_login_utc"])

# %%
# created_utc
df["created_utc"] = pd.to_datetime(df["created_utc"])

# %%
#Check whether username and email are unique.
df["username"].is_unique
# Out:
# True

# %%
# To check only particular column
df["email"].is_unique
# Out:
# True

# %%
#Identify which column behaves like an identifier (very high unique count).
df.nunique()
# Out:
# user_id           6000
# username          6000
# email             6000
# password_hash     6000
# password_salt     6000
# role                 4
# mfa_enabled          2
# last_login_utc    5269
# created_utc       5783
# dtype: int64

# %%
#Count how many records are fully duplicated rows
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Display only the username column
df["username"]
# Out:
# 0       user00001
# 1       user00002
# 2       user00003
# 3       user00004
# 4       user00005
#           ...
# 5995    user05996
# 5996    user05997
# 5997    user05998
# 5998    user05999
# 5999    user06000
# Name: username, Length: 6000, dtype: object

# %%
#Display the username and email columns together.
df[["username", "email"]]
# Out:
#        username                  email
# 0     user00001  user00001@example.com
# 1     user00002   user00002@corp.local
# 2     user00003  user00003@example.com
# 3     user00004    user00004@mail.test
# 4     user00005   user00005@corp.local
# ...         ...                    ...
# 5995  user05996  user05996@example.com
# 5996  user05997   user05997@corp.local
# 5997  user05998   user05998@service.io
# 5998  user05999   user05999@corp.local
# 5999  user06000   user06000@corp.local
#
# [6000 rows x 2 columns]

# %%
#What is the difference between:

df_users["email"]

df_users[["email"]]

# %%
#Access the first row using positional indexing.
df.iloc[0]
# Out:
# user_id                                                           1
# username                                                  user00001
# email                                         user00001@example.com
# password_hash     8d914e1cbb60b890c7399f2910cec96f8a5a8271363223...
# password_salt                                      bVrpoiVgRV5IfLBc
# role                                                        student
# mfa_enabled                                                    True
# last_login_utc                            2026-01-23 15:16:00+00:00
# created_utc                               2026-01-23 15:16:00+00:00
# Name: 0, dtype: object

# %%
#Access the first 5 rows using slicing.
df[:5]
# Out:
#    user_id   username                  email  \
# 0        1  user00001  user00001@example.com
# 1        2  user00002   user00002@corp.local
# 2        3  user00003  user00003@example.com
# 3        4  user00004    user00004@mail.test
# 4        5  user00005   user00005@corp.local
#
#                                        password_hash     password_salt  \
# 0  8d914e1cbb60b890c7399f2910cec96f8a5a8271363223...  bVrpoiVgRV5IfLBc
# 1  581e669218963490d73113876dde788b242cedd3bf6cfe...  SBvrjn9Wvgfygw2w
# 2  53a95abbb5fc355643afa051e051096dcccbcdad3332c5...  cQoXsf2o3gyrDO1x
# 3  8330d1676585fc69ec535bed89b7975db8b0a23501a8ff...  7OSJoRu1XXdo0cZu
# 4  f2889184f365ce51dd86bcdeaa4b03f74cd938666af404...  pVJIqVLB5LzxoiGF
#
#       role  mfa_enabled            last_login_utc               created_utc
# 0  student         True 2026-01-23 15:16:00+00:00 2026-01-23 15:16:00+00:00
# 1  student        False 2026-02-16 22:00:00+00:00 2026-01-02 22:00:00+00:00
# 2  student        False 2026-01-16 06:47:00+00:00 2025-12-23 06:47:00+00:00
# 3  student        False 2026-02-13 12:19:00+00:00 2026-01-28 12:19:00+00:00
# 4  student        False 2026-02-16 14:28:00+00:00 2026-01-12 14:28:00+00:00

# %%
#Access the 10th row (by position).
df.iloc[10]
# Out:
# user_id                                                          11
# username                                                  user00011
# email                                         user00011@example.com
# password_hash     2216a7d8714ce9cb290ac1c5af3028c16b33e2a59842cf...
# password_salt                                      dPI1af7W2pkAFEn3
# role                                                        student
# mfa_enabled                                                   False
# last_login_utc                            2026-02-20 14:05:00+00:00
# created_utc                               2026-01-20 14:05:00+00:00
# Name: 10, dtype: object

# %%
#Access the value of email in the 5th row using positional indexing.
df.iloc[5]["email"]
# Out:
# 'user00006@example.com'

# %%
#Access the record corresponding to user_id = 100.
df[df["user_id"] == 100]
# Out:
#     user_id   username               email  \
# 99      100  user00100  user00100@univ.edu
#
#                                         password_hash     password_salt  \
# 99  29e3bc5648e8a75eeebf9652fc2d102746ce96c2005f57...  DKdJDRZtUbzq0aVn
#
#        role mfa_enabled            last_login_utc               created_utc
# 99  student         NaN 2025-12-09 19:17:00+00:00 2025-12-06 19:17:00+00:00

# %%
#Access only the email of user_id = 100.
df[df["user_id"] == 100]["email"]
# Out:
# 99    user00100@univ.edu
# Name: email, dtype: object

# %%
#Access all records where role is admin.
df[df["role"] == "admin"]
# Out:
#       user_id   username                  email  \
# 20         21  user00021     user00021@univ.edu
# 27         28  user00028   user00028@corp.local
# 88         89  user00089   user00089@service.io
# 142       143  user00143   user00143@corp.local
# 151       152  user00152     user00152@univ.edu
# ...       ...        ...                    ...
# 5793     5794  user05794   user05794@service.io
# 5885     5886  user05886   user05886@corp.local
# 5910     5911  user05911  user05911@example.com
# 5917     5918  user05918  user05918@example.com
# 5923     5924  user05924     user05924@univ.edu
#
#                                           password_hash     password_salt  \
# 20    c1288b40d36e54c7b8b0b965a2cebc285e7fdc49b32bae...  YLMPuDCCRnGEY59Y
# 27    351a994c3fa9d9d639061cbc251de2c7987727a54f076a...  m1bNjpiEQhK8nDSq
# 88    4baba6c92e01a5a95a68582d36db2050a726d3ecbe9657...  IFTKtE0bxvRhALtY
# 142   87d27eb1865a0afe2cc8ebfd10ee603dbe5135abc98d45...  a7AboIwO1S4a8vaW
# 151   c9f1f529cda5a06940f137807b786b97f71dd9b4fe4c00...  av6NmZivTl6Z23ud
# ...                                                 ...               ...
# 5793  83053215feec3408ecdc1fd70acf9b9c8e067329d6e6f1...  lIzfqLkLeP73XC9w
# 5885  daa66b98daa0005b1732888b2c75451d0b0beafb107ebd...  FuwqxIxMk2qEX4AH
# 5910  3c834787ca48bf9f50ebbf81fd2156f199a8db66ea0c60...  ao5JHMbdOjXgMF2F
# 5917  a2385c5921322f0d58c4ba7ed46f5b6629250d825ba8b6...  2oCzak9lgl4UTrbw
# 5923  11b15db73100b604b5d6008839addc6a4e0a9d5ef3b08f...  d85NaHJNGEskMvTI
#
#        role mfa_enabled            last_login_utc               created_utc
# 20    admin         NaN 2026-01-10 06:07:00+00:00 2025-12-29 06:07:00+00:00
# 27    admin         NaN                       NaT 2025-12-03 08:05:00+00:00
# 88    admin         NaN 2026-01-27 17:04:00+00:00 2025-12-21 17:04:00+00:00
# 142   admin         NaN 2025-12-18 23:01:00+00:00 2025-12-13 23:01:00+00:00
# 151   admin         NaN 2026-01-27 00:11:00+00:00 2026-01-06 00:11:00+00:00
# ...     ...         ...                       ...                       ...
# 5793  admin         NaN 2026-01-25 11:57:00+00:00 2025-12-06 11:57:00+00:00
# 5885  admin         NaN 2025-12-18 07:18:00+00:00 2025-12-09 07:18:00+00:00
# 5910  admin         NaN                       NaT 2026-01-17 12:16:00+00:00
# 5917  admin         NaN 2026-02-16 16:25:00+00:00 2026-01-26 16:25:00+00:00
# 5923  admin         NaN 2026-01-17 10:25:00+00:00 2026-01-14 10:25:00+00:00
#
# [180 rows x 9 columns]

# %%
#Access all records where mfa_enabled is "0".

# %%
# Access records where role is staff AND mfa_enabled is "0".

# %%
#Access records where role is either admin OR staff.

# %%
#Access multiple users using index labels: user_id = 10, 20, 30.

# %%
#From users with mfa_enabled = "0", display only: user_id , username , email

# %%
#From users whose role is admin, display only: username , created_utc , last_login_utc

# %%
#Access users whose role is admin using query().

# %%
#Access users whose role is staff and MFA is disabled using query().
