# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DIR = '/content/drive/My Drive/Colab Notebooks/data'
datafile= 'superstore.csv'
filename = DIR+'/'+datafile

# %%
import os
os.chdir(DIR)

# %%
df = pd.read_csv(filename)

# %%
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156  11-08-2016  11-11-2016    Second Class
# 1          2  CA-2016-152156  11-08-2016  11-11-2016    Second Class
# 2          3  CA-2016-138688  06-12-2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10-11-2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10-11-2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017  03-03-2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017  03-03-2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017  03-03-2017  Standard Class
# 9993    9994  CA-2017-119914  05-04-2017  05-09-2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
#0->row label
df.loc[0]
# Out:
# Row ID                                           1
# Order ID                            CA-2016-152156
# Order Date                              11-08-2016
# Ship Date                               11-11-2016
# Ship Mode                             Second Class
# Customer ID                               CG-12520
# Customer Name                          Claire Gute
# Segment                                   Consumer
# Country                              United States
# City                                     Henderson
# State                                     Kentucky
# Postal Code                                  42420
# Region                                       South
# Product ID                         FUR-BO-10001798
# Category                                 Furniture
# Sub-Category                             Bookcases
# Product Name     Bush Somerset Collection Bookcase
# Sales                                       261.96
# ...

# %%
#label
df.loc[0:3]
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  11-08-2016  11-11-2016    Second Class    CG-12520
# 1       2  CA-2016-152156  11-08-2016  11-11-2016    Second Class    CG-12520
# 2       3  CA-2016-138688  06-12-2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10-11-2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# ...

# %%
#retrieve 3rd row 2nd column
df.loc[3,'Order ID']
# Out:
# 'US-2015-108966'

# %%
#retrieve 0th and 4th row
df.loc[[0,4]]
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  11-08-2016  11-11-2016    Second Class    CG-12520
# 4       5  US-2015-108966  10-11-2015  10/18/2015  Standard Class    SO-20335
#
#     Customer Name   Segment        Country             City  ... Postal Code  \
# 0     Claire Gute  Consumer  United States        Henderson  ...       42420
# 4  Sean O'Donnell  Consumer  United States  Fort Lauderdale  ...       33311
#
#    Region       Product ID         Category Sub-Category  \
# 0   South  FUR-BO-10001798        Furniture    Bookcases
# 4   South  OFF-ST-10000760  Office Supplies      Storage
#
#                         Product Name    Sales  Quantity  Discount   Profit
# 0  Bush Somerset Collection Bookcase  261.960         2       0.0  41.9136
# 4     Eldon Fold 'N Roll Cart System   22.368         2       0.2   2.5164
#
# [2 rows x 21 columns]

# %% [markdown]
# []-> single value or row
# [[]]->if we have to retreive more than 1 row or value

# %%
#with 1 column
df.loc[[0,3],['Order ID']]
# Out:
#          Order ID
# 0  CA-2016-152156
# 3  US-2015-108966

# %%
#2nd index with till which column
df.loc[3,:'Ship Mode']
# Out:
# Row ID                     4
# Order ID      US-2015-108966
# Order Date        10-11-2015
# Ship Date         10/18/2015
# Ship Mode     Standard Class
# Name: 3, dtype: object

# %%
#retrive all column with row 6
df.loc[6]
# Out:
# Row ID                         7
# Order ID          CA-2014-115812
# Order Date            06-09-2014
# Ship Date              6/14/2014
# Ship Mode         Standard Class
# Customer ID             BH-11710
# Customer Name    Brosina Hoffman
# Segment                 Consumer
# Country            United States
# City                 Los Angeles
# State                 California
# Postal Code                90032
# Region                      West
# Product ID       OFF-AR-10002833
# Category         Office Supplies
# Sub-Category                 Art
# Product Name          Newell 322
# Sales                       7.28
# Quantity                       4
# Discount                     0.0
# Profit                    1.9656
# Name: 6, dtype: object

# %%
#retrive last row
df.loc[df.shape[0]-1]
# Out:
# Row ID                                                        9994
# Order ID                                            CA-2017-119914
# Order Date                                              05-04-2017
# Ship Date                                               05-09-2017
# Ship Mode                                             Second Class
# Customer ID                                               CC-12220
# Customer Name                                         Chris Cortes
# Segment                                                   Consumer
# Country                                              United States
# City                                                   Westminster
# State                                                   California
# Postal Code                                                  92683
# Region                                                        West
# Product ID                                         OFF-AP-10002684
# ...

# %%
df.loc[[3,5,9,17]]
# Out:
#     Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 3        4  US-2015-108966  10-11-2015  10/18/2015  Standard Class
# 5        6  CA-2014-115812  06-09-2014   6/14/2014  Standard Class
# 9       10  CA-2014-115812  06-09-2014   6/14/2014  Standard Class
# 17      18  CA-2014-167164   5/13/2014   5/15/2014    Second Class
#
#    Customer ID    Customer Name   Segment        Country             City  \
# 3     SO-20335   Sean O'Donnell  Consumer  United States  Fort Lauderdale
# 5     BH-11710  Brosina Hoffman  Consumer  United States      Los Angeles
# 9     BH-11710  Brosina Hoffman  Consumer  United States      Los Angeles
# 17    AG-10270  Alejandro Grove  Consumer  United States      West Jordan
#
#     ... Postal Code  Region       Product ID         Category Sub-Category  \
# 3   ...       33311   South  FUR-TA-10000577        Furniture       Tables
# 5   ...       90032    West  FUR-FU-10001487        Furniture  Furnishings
# ...
